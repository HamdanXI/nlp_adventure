# %% [markdown]
# <a href="https://colab.research.google.com/github/HamdanXI/nlp_adventure/blob/main/paradetox-preprocess-maskedComments-noINSERT-noPunctationComparision.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install datasets
# !apt install git-lfs

# %%
from huggingface_hub import notebook_login

notebook_login()
# Out:
# VBox(children=(HTML(value='<center> <img\nsrc=https://huggingface.co/front/assets/huggingface_logo-noborder.sv…

# %%
from datasets import load_dataset
import re

dataset = load_dataset("HamdanXI/paradetox-preprocess")
# Out:
# Downloading readme:   0%|          | 0.00/508 [00:00<?, ?B/s]
# Downloading data files:   0%|          | 0/1 [00:00<?, ?it/s]
# Downloading data:   0%|          | 0.00/1.22M [00:00<?, ?B/s]
# Extracting data files:   0%|          | 0/1 [00:00<?, ?it/s]
# Generating train split:   0%|          | 0/19744 [00:00<?, ? examples/s]

# %%
dataset
# Out:
# DatasetDict({
#     train: Dataset({
#         features: ['en_toxic_comment', 'en_neutral_comment'],
#         num_rows: 19744
#     })
# })

# %%
import difflib

def get_diff_ops(original, edited):
    try:
        ops = []
        original_words = original.split()
        edited_words = edited.split()
        s = difflib.SequenceMatcher(None, original_words, edited_words)

        for tag, i1, i2, j1, j2 in s.get_opcodes():
            if tag == 'delete':
                for i in range(i1, i2):
                    ops.append(("delete", original_words[i], i))
            elif tag == 'insert':
                for j in range(j1, j2):
                    ops.append(("insert", edited_words[j], j1))
            elif tag == 'replace':
                max_replace = max(i2 - i1, j2 - j1)
                for i in range(max_replace):
                    orig_word = original_words[i1 + i] if i1 + i < i2 else None
                    new_word = edited_words[j1 + i] if j1 + i < j2 else None
                    if orig_word and new_word:
                        ops.append(("replace", orig_word, i1 + i, new_word))
                    elif orig_word:
                        ops.append(("delete", orig_word, i1 + i))
                    elif new_word:
                        ops.append(("insert", new_word, j1 + i))
        return ops
    except Exception as e:
        print(f"Error with original: {original} and edited: {edited}. Error: {e}")
        return []


def apply_diff_ops(example):
    original = example['en_toxic_comment']
    edited = example['en_neutral_comment']

    ops_list = get_diff_ops(original, edited)
    original_words = original.split()

    # Track the shifts caused by previous insertions
    shifts = 0
    # Initialize an empty list to hold formatted operations for the new column
    formatted_ops = []

    for op in ops_list:
      op_type, word, index, *rest = op
      if op_type == 'delete':
          original_words[index + shifts] = '[DELETE]'
          formatted_ops.append((op_type, word, str(index)))  # Convert index to string
      elif op_type == 'insert':
          original_words.insert(index + shifts, '[INSERT]')
          shifts += 1  # Increment the shift for subsequent indexes
          formatted_ops.append((op_type, word, str(index + shifts)))  # Convert index to string
      elif op_type == 'replace':
          original_words[index + shifts] = '[REPLACE]'
          formatted_ops.append((op_type, word, str(index + shifts), rest[0]))  # Convert index to string


    # Join the masked_comment list back into a single string
    masked_comment = ' '.join(original_words)

    # Add the masked comment and formatted operations to the example
    example['edit_ops'] = formatted_ops
    example['masked_comment'] = masked_comment
    return example

# %%
dataset_with_ops = dataset.map(apply_diff_ops)
# Out:
# Map:   0%|          | 0/19744 [00:00<?, ? examples/s]

# %%
dataset_with_ops.push_to_hub("paradetox-preprocess-maskedComments")
# Out:
# Pushing dataset shards to the dataset hub:   0%|          | 0/1 [00:00<?, ?it/s]
# Creating parquet from Arrow format:   0%|          | 0/20 [00:00<?, ?ba/s]

# %%
dataset_with_ops['train'][0]
# Out:
# {'en_toxic_comment': 'he had steel balls too!',
#  'en_neutral_comment': 'he was brave too!',
#  'edit_ops': [['replace', 'had', '1', 'was'],
#   ['replace', 'steel', '2', 'brave'],
#   ['delete', 'balls', '3']],
#  'masked_comment': 'he [REPLACE] [REPLACE] [DELETE] too!'}

# %%
import difflib

def get_diff_ops(original, edited):
    try:
        ops = []
        original_words = original.split()
        edited_words = edited.split()
        s = difflib.SequenceMatcher(None, original_words, edited_words)

        for tag, i1, i2, j1, j2 in s.get_opcodes():
            if tag == 'delete':
                for i in range(i1, i2):
                    ops.append(("delete", original_words[i], i))
            elif tag == 'insert':
                for j in range(j1, j2):
                    ops.append(("insert", edited_words[j], j1))
            elif tag == 'replace':
                max_replace = max(i2 - i1, j2 - j1)
                for i in range(max_replace):
                    orig_word = original_words[i1 + i] if i1 + i < i2 else None
                    new_word = edited_words[j1 + i] if j1 + i < j2 else None
                    if orig_word and new_word:
                        ops.append(("replace", orig_word, i1 + i, new_word))
                    elif orig_word:
                        ops.append(("delete", orig_word, i1 + i))
                    elif new_word:
                        ops.append(("insert", new_word, j1 + i))
        return ops
    except Exception as e:
        print(f"Error with original: {original} and edited: {edited}. Error: {e}")
        return []


def apply_diff_ops(example):
    original = example['en_toxic_comment']
    edited = example['en_neutral_comment']

    ops_list = get_diff_ops(original, edited)
    original_words = original.split()

    masked_comment = original_words.copy()

    # Track the shifts caused by previous insertions and deletions
    formatted_ops = []

    for op in ops_list:
        op_type, word, index, *rest = op
        if op_type == 'delete':
            masked_comment[index] = '[DELETE]'
            formatted_ops.append((op_type, word, str(index)))  # Convert index to string
        elif op_type == 'insert':
            # Since 'insert' doesn't replace an existing word, we skip it for masking purposes
            pass
        elif op_type == 'replace':
            masked_comment[index] = '[REPLACE]'
            formatted_ops.append((op_type, word, str(index), rest[0]))  # Convert index to string

    masked_comment = ' '.join(masked_comment)

    # Add the masked comment and formatted operations to the example
    example['edit_ops'] = formatted_ops
    example['masked_comment'] = masked_comment
    return example

# %%
dataset_with_ops_no_Insert = dataset.map(apply_diff_ops)

# %%
dataset_with_ops_no_Insert['train'][8]
# Out:
# {'en_toxic_comment': 'delete the page and shut up.',
#  'en_neutral_comment': 'please delete the page.',
#  'edit_ops': [['replace', 'page', '2', 'page.'],
#   ['delete', 'and', '3'],
#   ['delete', 'shut', '4'],
#   ['delete', 'up.', '5']],
#  'masked_comment': 'delete the [REPLACE] [DELETE] [DELETE] [DELETE]'}

# %%
dataset_with_ops_no_Insert.push_to_hub("paradetox-preprocess-maskedComments-without-INSERT")
# Out:
# Pushing dataset shards to the dataset hub:   0%|          | 0/1 [00:00<?, ?it/s]
# Creating parquet from Arrow format:   0%|          | 0/20 [00:00<?, ?ba/s]
# Deleting unused files from dataset repository:   0%|          | 0/1 [00:00<?, ?it/s]
# Downloading metadata:   0%|          | 0.00/637 [00:00<?, ?B/s]

# %%
import difflib
import string

def get_diff_ops(original, edited):
    try:
        ops = []
        # Remove punctuation from the strings
        original_no_punct = original.translate(str.maketrans('', '', string.punctuation))
        edited_no_punct = edited.translate(str.maketrans('', '', string.punctuation))

        original_words = original_no_punct.split()
        edited_words = edited_no_punct.split()
        s = difflib.SequenceMatcher(None, original_words, edited_words)

        for tag, i1, i2, j1, j2 in s.get_opcodes():
            if tag == 'delete':
                for i in range(i1, i2):
                    ops.append(("delete", original_words[i], i))
            elif tag == 'insert':
                for j in range(j1, j2):
                    ops.append(("insert", edited_words[j], j1))
            elif tag == 'replace':
                max_replace = max(i2 - i1, j2 - j1)
                for i in range(max_replace):
                    orig_word = original_words[i1 + i] if i1 + i < i2 else None
                    new_word = edited_words[j1 + i] if j1 + i < j2 else None
                    if orig_word and new_word:
                        ops.append(("replace", orig_word, i1 + i, new_word))
                    elif orig_word:
                        ops.append(("delete", orig_word, i1 + i))
                    elif new_word:
                        ops.append(("insert", new_word, j1 + i))
        return ops
    except Exception as e:
        print(f"Error with original: {original} and edited: {edited}. Error: {e}")
        return []

def apply_diff_ops(example):
    original = example['en_toxic_comment']
    edited = example['en_neutral_comment']

    ops_list = get_diff_ops(original, edited)
    original_words = original.split()

    masked_comment = original_words.copy()

    # Track the shifts caused by previous insertions and deletions
    formatted_ops = []

    for op in ops_list:
        op_type, word, index, *rest = op
        if op_type == 'delete':
            masked_comment[index] = '[DELETE]'
            formatted_ops.append((op_type, word, str(index)))  # Convert index to string
        elif op_type == 'insert':
            # Since 'insert' doesn't replace an existing word, we skip it for masking purposes
            pass
        elif op_type == 'replace':
            masked_comment[index] = '[REPLACE]'
            formatted_ops.append((op_type, word, str(index), rest[0]))  # Convert index to string

    masked_comment = ' '.join(masked_comment)

    # Add the masked comment and formatted operations to the example
    example['edit_ops'] = formatted_ops
    example['masked_comment'] = masked_comment
    return example

# %%
dataset_with_ops_no_Insert_no_punctationComparision = dataset.map(apply_diff_ops)
# Out:
# Map:   0%|          | 0/19744 [00:00<?, ? examples/s]

# %%
dataset_with_ops_no_Insert_no_punctationComparision['train'][8]
# Out:
# {'en_toxic_comment': 'delete the page and shut up.',
#  'en_neutral_comment': 'please delete the page.',
#  'edit_ops': [['delete', 'and', '3'],
#   ['delete', 'shut', '4'],
#   ['delete', 'up', '5']],
#  'masked_comment': 'delete the page [DELETE] [DELETE] [DELETE]'}

# %%
dataset_with_ops_no_Insert_no_punctationComparision['train'][7]
# Out:
# {'en_toxic_comment': 'stop the coverage and let em rot.',
#  'en_neutral_comment': 'kindly stop the coverage.',
#  'edit_ops': [['delete', 'and', '3'],
#   ['delete', 'let', '4'],
#   ['delete', 'em', '5'],
#   ['delete', 'rot', '6']],
#  'masked_comment': 'stop the coverage [DELETE] [DELETE] [DELETE] [DELETE]'}

# %%
dataset_with_ops_no_Insert_no_punctationComparision.push_to_hub("paradetox-preprocess-maskedComments-without-INSERT-without-punctationComparision")
# Out:
# Pushing dataset shards to the dataset hub:   0%|          | 0/1 [00:00<?, ?it/s]
# Creating parquet from Arrow format:   0%|          | 0/20 [00:00<?, ?ba/s]
