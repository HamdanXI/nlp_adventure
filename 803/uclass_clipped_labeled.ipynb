# %%
import pandas as pd
from pydub import AudioSegment
import os

# %%
# Assuming all CSV files and MP3 files are in the same directory
csv_directory = 'csv'
audio_directory = 'audio'
output_directory = 'output'

# Create output directory if it doesn't exist
os.makedirs(output_directory, exist_ok=True)

# List all CSV and MP3 files
csv_files = [f for f in os.listdir(csv_directory) if f.endswith('.csv')]
audio_files = [f for f in os.listdir(audio_directory) if f.endswith('.mp3')]

# %%
for csv_file in csv_files:
    audio_file = csv_file.replace('.csv', '.mp3')
    csv_path = os.path.join(csv_directory, csv_file)
    
    try:
        df = pd.read_csv(csv_path, header=None, usecols=[0, 2, 3, 7])
    except UnicodeDecodeError:
        df = pd.read_csv(csv_path, header=None, usecols=[0, 2, 3, 7], encoding='cp1252')  # You can try 'iso-8859-1' or 'cp1252'
    
    audio_path = os.path.join(audio_directory, audio_file)
    audio = AudioSegment.from_mp3(audio_path)

    for index, row in df.iterrows():
        start_time = int(row[2] * 1000)
        end_time = int(row[3] * 1000)
        segment = audio[start_time:end_time]

        segment_filename = f"{os.path.splitext(audio_file)[0]}_segment_{index}.mp3"
        segment_path = os.path.join(output_directory, segment_filename)
        segment.export(segment_path, format='mp3')

        df.loc[index, 'audio_clip_path'] = segment_path

    modified_csv_path = os.path.join(csv_directory, f"modified_{csv_file}")
    df.to_csv(modified_csv_path, index=False)

print("Audio processing complete. Modified CSVs and audio clips are saved.")
# Out:
# Audio processing complete. Modified CSVs and audio clips are saved.

# %%
from datasets import Dataset, Audio, DatasetDict
from huggingface_hub import HfApi, HfFolder, Repository
import pandas as pd
import os

# Directories
csv_directory = 'csv'
audio_segment_directory = 'output'

# List all segment files
audio_files = [f for f in os.listdir(audio_segment_directory) if f.endswith('.mp3')]
audio_files.sort()

# %%
# Initialize dataset list
data = []

# Process each audio segment file
for audio_file in audio_files:
    # Find the corresponding CSV file and row index
    base_name = "_".join(audio_file.split("_")[:-2]) + ".csv"
    # index = int(audio_file.split("_")[-1].replace('.mp3', ''))
    segment_index = int(audio_file.split("_")[-1].replace('.mp3', ''))  # segment index

    # Load the CSV file
    csv_path = os.path.join(csv_directory, base_name)
    
    try:
        df = pd.read_csv(csv_path, header=None, usecols=[0, 2, 3, 7])
    except UnicodeDecodeError:
        df = pd.read_csv(csv_path, header=None, usecols=[0, 2, 3, 7], encoding='cp1252')  # You can try 'iso-8859-1' or 'cp1252'
    
    
    # df = pd.read_csv(csv_path, header=None, usecols=[0, 2, 3, 7])

    # Retrieve metadata from the CSV file
    # utterance_word = df.iloc[index][0]
    # class_label = df.iloc[index][7]
    utterance_word = df.iloc[segment_index][0]
    class_label = df.iloc[segment_index][7]
    
    # Full path to the audio file
    full_path = os.path.join(audio_segment_directory, audio_file)

    # Append to data list
    data.append({
        'path': full_path,
        'utterance': utterance_word,
        'class': class_label
    })

# %%
data
# Out:
# [{'path': 'output\\F_0101_10y4m_1_segment_0.mp3',
#   'utterance': 'and',
#   'class': 0},
#  {'path': 'output\\F_0101_10y4m_1_segment_1.mp3',
#   'utterance': 'yjeu',
#   'class': 0},
#  {'path': 'output\\F_0101_10y4m_1_segment_10.mp3',
#   'utterance': 'it',
#   'class': 0},
#  {'path': 'output\\F_0101_10y4m_1_segment_11.mp3',
#   'utterance': 'UM',
#   'class': 1},
#  {'path': 'output\\F_0101_10y4m_1_segment_12.mp3',
#   'utterance': 'they',
#   'class': 0},
#  {'path': 'output\\F_0101_10y4m_1_segment_13.mp3',
#   'utterance': 'had',
#   'class': 0},
#  {'path': 'output\\F_0101_10y4m_1_segment_14.mp3',
#   'utterance': 'animation',
#   'class': 0},
#  {'path': 'output\\F_0101_10y4m_1_segment_15.mp3',
#   'utterance': 'and',
#   'class': 0},
#  {'path': 'output\\F_0101_10y4m_1_segment_16.mp3',
#   'utterance': 'UM',
#   'class': 1},
#  {'path': 'output\\F_0101_10y4m_1_segment_17.mp3',
#   'utterance': 'computer',
#   'class': 0},
#  {'path': 'output\\F_0101_10y4m_1_segment_18.mp3',
#   'utterance': 'work',
#   'class': 0},
#  {'path': 'output\\F_0101_10y4m_1_segment_19.mp3',
#   'utterance': 'UM',
#   'class': 1},
#  {'path': 'output\\F_0101_10y4m_1_segment_2.mp3',
#   'utterance': 'went',
#   'class': 0},
#  {'path': 'output\\F_0101_10y4m_1_segment_20.mp3',
#   'utterance': 'it',
#   'class': 0},
#  {'path': 'output\\F_0101_10y4m_1_segment_21.mp3',
#   'utterance': 'was',
#   'class': 0},
#  {'path': 'output\\F_0101_10y4m_1_segment_22.mp3',
#   'utterance': 'quite',
#   'class': 0},
#  {'path': 'output\\F_0101_10y4m_1_segment_23.mp3',
#   'utterance': 'FU',
#   'class': 2},
#  {'path': 'output\\F_0101_10y4m_1_segment_24.mp3',
#   'utterance': 'FUNNY',
#   'class': 2},
#  {'path': 'output\\F_0101_10y4m_1_segment_25.mp3',
#   'utterance': 'UM',
#   'class': 1},
#  {'path': 'output\\F_0101_10y4m_1_segment_26.mp3',
#   'utterance': 'it',
#   'class': 0},
#  {'path': 'output\\F_0101_10y4m_1_segment_27.mp3',
#   'utterance': 'was',
#   'class': 0},
#  {'path': 'output\\F_0101_10y4m_1_segment_28.mp3',
#   'utterance': 'about',
#   'class': 0},
#  {'path': 'output\\F_0101_10y4m_1_segment_29.mp3',
#   'utterance': 'this',
#   'class': 0},
#  {'path': 'output\\F_0101_10y4m_1_segment_3.mp3',
#   'utterance': 'off',
#   'class': 0},
#  {'path': 'output\\F_0101_10y4m_1_segment_30.mp3',
#   'utterance': 'UM',
#   'class': 1},
#  {'path': 'output\\F_0101_10y4m_1_segment_31.mp3',
#   'utterance': 'girl',
#   'class': 0},
#  {'path': 'output\\F_0101_10y4m_1_segment_32.mp3',
#   'utterance': 'WHO',
#   'class': 4},
#  {'path': 'output\\F_0101_10y4m_1_segment_33.mp3',
#   'utterance': 'was',
#   'class': 0},
#  {'path': 'output\\F_0101_10y4m_1_segment_34.mp3',
#   'utterance': 'a',
#   'class': 0},
#  {'path': 'output\\F_0101_10y4m_1_segment_35.mp3',
#   'utterance': 'PRI',
#   'class': 2},
#  {'path': 'output\\F_0101_10y4m_1_segment_36.mp3',
#   'utterance': 'PRINCESS',
#   'class': 2},
#  {'path': 'output\\F_0101_10y4m_1_segment_37.mp3',
#   'utterance': 'but',
#   'class': 0},
#  {'path': 'output\\F_0101_10y4m_1_segment_38.mp3',
#   'utterance': 'then',
#   'class': 0},
#  {'path': 'output\\F_0101_10y4m_1_segment_39.mp3',
#   'utterance': 'got',
#   'class': 0},
#  {'path': 'output\\F_0101_10y4m_1_segment_4.mp3',
#   'utterance': 'i',
#   'class': 0},
#  {'path': 'output\\F_0101_10y4m_1_segment_40.mp3',
#   'utterance': 'SSSSSSPLIT',
#   'class': 2},
#  {'path': 'output\\F_0101_10y4m_1_segment_41.mp3',
#   'utterance': 'up',
#   'class': 0},
#  {'path': 'output\\F_0101_10y4m_1_segment_42.mp3',
#   'utterance': 'with',
#   'class': 0},
#  {'path': 'output\\F_0101_10y4m_1_segment_43.mp3',
#   'utterance': 'her',
#   'class': 0},
#  {'path': 'output\\F_0101_10y4m_1_segment_44.mp3',
#   'utterance': 'FA',
#   'class': 2},
#  {'path': 'output\\F_0101_10y4m_1_segment_45.mp3',
#   'utterance': 'FAMILY',
#   'class': 2},
#  {'path': 'output\\F_0101_10y4m_1_segment_46.mp3',
#   'utterance': 'and',
#   'class': 2},
#  {'path': 'output\\F_0101_10y4m_1_segment_47.mp3',
#   'utterance': 'AND',
#   'class': 2},
#  {'path': 'output\\F_0101_10y4m_1_segment_48.mp3',
#   'utterance': 'she',
#   'class': 0},
#  {'path': 'output\\F_0101_10y4m_1_segment_49.mp3',
#   'utterance': 'was',
#   'class': 0},
#  {'path': 'output\\F_0101_10y4m_1_segment_5.mp3',
#   'utterance': 'seen',
#   'class': 0},
#  {'path': 'output\\F_0101_10y4m_1_segment_50.mp3',
#   'utterance': 'trying',
#   'class': 0},
#  {'path': 'output\\F_0101_10y4m_1_segment_51.mp3',
#   'utterance': 'to',
#   'class': 0},
#  {'path': 'output\\F_0101_10y4m_1_segment_52.mp3',
#   'utterance': 'UM',
#   'class': 1},
#  {'path': 'output\\F_0101_10y4m_1_segment_53.mp3',
#   'utterance': 'get',
#   'class': 0},
#  {'path': 'output\\F_0101_10y4m_1_segment_54.mp3',
#   'utterance': 'BACK',
#   'class': 0},
#  {'path': 'output\\F_0101_10y4m_1_segment_55.mp3',
#   'utterance': 'to',
#   'class': 0},
#  {'path': 'output\\F_0101_10y4m_1_segment_56.mp3',
#   'utterance': 'them',
#   'class': 0},
#  {'path': 'output\\F_0101_10y4m_1_segment_57.mp3',
#   'utterance': 'UM',
#   'class': 1},
#  {'path': 'output\\F_0101_10y4m_1_segment_58.mp3',
#   'utterance': 'UM',
#   'class': 1},
#  {'path': 'output\\F_0101_10y4m_1_segment_59.mp3',
#   'utterance': 'someone',
#   'class': 0},
#  {'path': 'output\\F_0101_10y4m_1_segment_6.mp3',
#   'utterance': 'UM',
#   'class': 1},
#  {'path': 'output\\F_0101_10y4m_1_segment_60.mp3',
#   'utterance': 'had',
#   'class': 0},
#  {'path': 'output\\F_0101_10y4m_1_segment_61.mp3',
#   'utterance': 'UM',
#   'class': 1},
#  {'path': 'output\\F_0101_10y4m_1_segment_62.mp3',
#   'utterance': 'U',
#   'class': 1},
#  {'path': 'output\\F_0101_10y4m_1_segment_63.mp3',
#   'utterance': 'U',
#   'class': 1},
#  {'path': 'output\\F_0101_10y4m_1_segment_64.mp3',
#   'utterance': 'UM',
#   'class': 1},
#  {'path': 'output\\F_0101_10y4m_1_segment_65.mp3',
#   'utterance': 'she',
#   'class': 0},
#  {'path': 'output\\F_0101_10y4m_1_segment_66.mp3',
#   'utterance': "didn't",
#   'class': 0},
#  {'path': 'output\\F_0101_10y4m_1_segment_67.mp3',
#   'utterance': 'quite',
#   'class': 0},
#  {'path': 'output\\F_0101_10y4m_1_segment_68.mp3',
#   'utterance': 'make',
#   'class': 0},
#  {'path': 'output\\F_0101_10y4m_1_segment_69.mp3',
#   'utterance': 'it',
#   'class': 0},
#  {'path': 'output\\F_0101_10y4m_1_segment_7.mp3',
#   'utterance': 'IN',
#   'class': 4},
#  {'path': 'output\\F_0101_10y4m_1_segment_70.mp3',
#   'utterance': 'to',
#   'class': 0},
#  {'path': 'output\\F_0101_10y4m_1_segment_71.mp3',
#   'utterance': 'UM',
#   'class': 1},
#  {'path': 'output\\F_0101_10y4m_1_segment_72.mp3',
#   'utterance': 'the',
#   'class': 0},
#  {'path': 'output\\F_0101_10y4m_1_segment_73.mp3',
#   'utterance': 'train',
#   'class': 0},
#  {'path': 'output\\F_0101_10y4m_1_segment_74.mp3',
#   'utterance': 'And',
#   'class': 0},
#  {'path': 'output\\F_0101_10y4m_1_segment_75.mp3',
#   'utterance': 'she',
#   'class': 0},
#  {'path': 'output\\F_0101_10y4m_1_segment_76.mp3',
#   'utterance': 'UM',
#   'class': 1},
#  {'path': 'output\\F_0101_10y4m_1_segment_77.mp3',
#   'utterance': 'FE',
#   'class': 2},
#  {'path': 'output\\F_0101_10y4m_1_segment_78.mp3',
#   'utterance': 'FELL',
#   'class': 2},
#  {'path': 'output\\F_0101_10y4m_1_segment_79.mp3',
#   'utterance': 'off',
#   'class': 0},
#  {'path': 'output\\F_0101_10y4m_1_segment_8.mp3',
#   'utterance': 'I',
#   'class': 4},
#  {'path': 'output\\F_0101_10y4m_1_segment_80.mp3',
#   'utterance': 'the',
#   'class': 0},
#  {'path': 'output\\F_0101_10y4m_1_segment_81.mp3',
#   'utterance': 'train',
#   'class': 0},
#  {'path': 'output\\F_0101_10y4m_1_segment_82.mp3',
#   'utterance': 'UM',
#   'class': 1},
#  {'path': 'output\\F_0101_10y4m_1_segment_83.mp3',
#   'utterance': 'and',
#   'class': 0},
#  {'path': 'output\\F_0101_10y4m_1_segment_84.mp3',
#   'utterance': 'she',
#   'class': 0},
#  {'path': 'output\\F_0101_10y4m_1_segment_85.mp3',
#   'utterance': 'went',
#   'class': 0},
#  {'path': 'output\\F_0101_10y4m_1_segment_86.mp3',
#   'utterance': 'to',
#   'class': 0},
#  {'path': 'output\\F_0101_10y4m_1_segment_87.mp3',
#   'utterance': 'an',
#   'class': 0},
#  {'path': 'output\\F_0101_10y4m_1_segment_88.mp3',
#   'utterance': 'ORPHANAGEEE',
#   'class': 7},
#  {'path': 'output\\F_0101_10y4m_1_segment_89.mp3',
#   'utterance': 'UM',
#   'class': 1},
#  {'path': 'output\\F_0101_10y4m_1_segment_9.mp3',
#   'utterance': 'IN',
#   'class': 4},
#  {'path': 'output\\F_0101_10y4m_1_segment_90.mp3',
#   'utterance': 'Where',
#   'class': 0},
#  {'path': 'output\\F_0101_10y4m_1_segment_91.mp3',
#   'utterance': 'she',
#   'class': 0},
#  {'path': 'output\\F_0101_10y4m_1_segment_92.mp3',
#   'utterance': 'UM',
#   'class': 1},
#  {'path': 'output\\F_0101_13y1m_1_segment_0.mp3',
#   'utterance': 'ERM',
#   'class': 1},
#  {'path': 'output\\F_0101_13y1m_1_segment_1.mp3',
#   'utterance': 'for',
#   'class': 0},
#  {'path': 'output\\F_0101_13y1m_1_segment_10.mp3',
#   'utterance': 'got',
#   'class': 0},
#  {'path': 'output\\F_0101_13y1m_1_segment_100.mp3',
#   'utterance': 'HOA',
#   'class': 2},
#  {'path': 'output\\F_0101_13y1m_1_segment_101.mp3',
#   'utterance': 'HOLES',
#   'class': 2},
#  {'path': 'output\\F_0101_13y1m_1_segment_102.mp3',
#   'utterance': 'in',
#   'class': 0},
#  {'path': 'output\\F_0101_13y1m_1_segment_103.mp3',
#   'utterance': 'and',
#   'class': 0},
#  {'path': 'output\\F_0101_13y1m_1_segment_104.mp3',
#   'utterance': 'you',
#   'class': 0},
#  {'path': 'output\\F_0101_13y1m_1_segment_105.mp3',
#   'utterance': 'put',
#   'class': 0},
#  {'path': 'output\\F_0101_13y1m_1_segment_106.mp3',
#   'utterance': 'balls',
#   'class': 0},
#  {'path': 'output\\F_0101_13y1m_1_segment_107.mp3',
#   'utterance': 'in',
#   'class': 0},
#  {'path': 'output\\F_0101_13y1m_1_segment_108.mp3',
#   'utterance': 'it',
#   'class': 0},
#  {'path': 'output\\F_0101_13y1m_1_segment_109.mp3',
#   'utterance': 'AND',
#   'class': 4},
#  {'path': 'output\\F_0101_13y1m_1_segment_11.mp3',
#   'utterance': 'a',
#   'class': 0},
#  {'path': 'output\\F_0101_13y1m_1_segment_110.mp3',
#   'utterance': 'UM',
#   'class': 1},
#  {'path': 'output\\F_0101_13y1m_1_segment_111.mp3',
#   'utterance': 'AND',
#   'class': 4},
#  {'path': 'output\\F_0101_13y1m_1_segment_112.mp3',
#   'utterance': "they're",
#   'class': 0},
#  {'path': 'output\\F_0101_13y1m_1_segment_113.mp3',
#   'utterance': 'meant',
#   'class': 0},
#  {'path': 'output\\F_0101_13y1m_1_segment_114.mp3',
#   'utterance': 'to',
#   'class': 0},
#  {'path': 'output\\F_0101_13y1m_1_segment_115.mp3',
#   'utterance': 'put',
#   'class': 0},
#  {'path': 'output\\F_0101_13y1m_1_segment_116.mp3',
#   'utterance': 'their',
#   'class': 0},
#  {'path': 'output\\F_0101_13y1m_1_segment_117.mp3',
#   'utterance': 'paws',
#   'class': 0},
#  {'path': 'output\\F_0101_13y1m_1_segment_118.mp3',
#   'utterance': 'in',
#   'class': 0},
#  {'path': 'output\\F_0101_13y1m_1_segment_119.mp3',
#   'utterance': 'and',
#   'class': 0},
#  {'path': 'output\\F_0101_13y1m_1_segment_12.mp3',
#   'utterance': 'small',
#   'class': 0},
#  {'path': 'output\\F_0101_13y1m_1_segment_120.mp3',
#   'utterance': 'UM',
#   'class': 1},
#  {'path': 'output\\F_0101_13y1m_1_segment_121.mp3',
#   'utterance': 'play',
#   'class': 0},
#  {'path': 'output\\F_0101_13y1m_1_segment_122.mp3',
#   'utterance': 'with',
#   'class': 0},
#  {'path': 'output\\F_0101_13y1m_1_segment_123.mp3',
#   'utterance': 'that',
#   'class': 0},
#  {'path': 'output\\F_0101_13y1m_1_segment_124.mp3',
#   'utterance': 'And',
#   'class': 0},
#  {'path': 'output\\F_0101_13y1m_1_segment_125.mp3',
#   'utterance': 'they',
#   'class': 0},
#  {'path': 'output\\F_0101_13y1m_1_segment_126.mp3',
#   'utterance': 'quite',
#   'class': 0},
#  {'path': 'output\\F_0101_13y1m_1_segment_127.mp3',
#   'utterance': 'like',
#   'class': 0},
#  {'path': 'output\\F_0101_13y1m_1_segment_128.mp3',
#   'utterance': 'that',
#   'class': 0},
#  {'path': 'output\\F_0101_13y1m_1_segment_129.mp3',
#   'utterance': 'THEY',
#   'class': 4},
#  {'path': 'output\\F_0101_13y1m_1_segment_13.mp3',
#   'utterance': 'cat',
#   'class': 0},
#  {'path': 'output\\F_0101_13y1m_1_segment_130.mp3',
#   'utterance': "THEY'VE",
#   'class': 4},
#  {'path': 'output\\F_0101_13y1m_1_segment_131.mp3',
#   'utterance': 'been',
#   'class': 0},
#  {'path': 'output\\F_0101_13y1m_1_segment_132.mp3',
#   'utterance': 'playing',
#   'class': 0},
#  {'path': 'output\\F_0101_13y1m_1_segment_133.mp3',
#   'utterance': 'with',
#   'class': 0},
#  {'path': 'output\\F_0101_13y1m_1_segment_134.mp3',
#   'utterance': 'it',
#   'class': 0},
#  {'path': 'output\\F_0101_13y1m_1_segment_135.mp3',
#   'utterance': 'quite',
#   'class': 0},
#  {'path': 'output\\F_0101_13y1m_1_segment_136.mp3',
#   'utterance': 'a',
#   'class': 0},
#  {'path': 'output\\F_0101_13y1m_1_segment_137.mp3',
#   'utterance': 'lot',
#   'class': 0},
#  {'path': 'output\\F_0101_13y1m_1_segment_138.mp3',
#   'utterance': 'UM',
#   'class': 1},
#  {'path': 'output\\F_0101_13y1m_1_segment_139.mp3',
#   'utterance': 'we',
#   'class': 0},
#  {'path': 'output\\F_0101_13y1m_1_segment_14.mp3',
#   'utterance': 'bear',
#   'class': 0},
#  {'path': 'output\\F_0101_13y1m_1_segment_140.mp3',
#   'utterance': 'went',
#   'class': 0},
#  {'path': 'output\\F_0101_13y1m_1_segment_141.mp3',
#   'utterance': 'out',
#   'class': 0},
#  {'path': 'output\\F_0101_13y1m_1_segment_142.mp3',
#   'utterance': 'for',
#   'class': 0},
#  {'path': 'output\\F_0101_13y1m_1_segment_143.mp3',
#   'utterance': 'a',
#   'class': 0},
#  {'path': 'output\\F_0101_13y1m_1_segment_144.mp3',
#   'utterance': 'meal',
#   'class': 0},
#  {'path': 'output\\F_0101_13y1m_1_segment_145.mp3',
#   'utterance': 'on',
#   'class': 0},
#  {'path': 'output\\F_0101_13y1m_1_segment_146.mp3',
#   'utterance': 'Christmas',
#   'class': 0},
#  {'path': 'output\\F_0101_13y1m_1_segment_147.mp3',
#   'utterance': 'Day',
#   'class': 0},
#  {'path': 'output\\F_0101_13y1m_1_segment_148.mp3',
#   'utterance': 'to',
#   'class': 0},
#  {'path': 'output\\F_0101_13y1m_1_segment_149.mp3',
#   'utterance': 'this',
#   'class': 0},
#  {'path': 'output\\F_0101_13y1m_1_segment_15.mp3',
#   'utterance': "that's",
#   'class': 0},
#  {'path': 'output\\F_0101_13y1m_1_segment_150.mp3',
#   'utterance': 'pub',
#   'class': 0},
#  {'path': 'output\\F_0101_13y1m_1_segment_151.mp3',
#   'utterance': 'place',
#   'class': 0},
#  {'path': 'output\\F_0101_13y1m_1_segment_152.mp3',
#   'utterance': 'which',
#   'class': 0},
#  {'path': 'output\\F_0101_13y1m_1_segment_153.mp3',
#   'utterance': 'was',
#   'class': 0},
#  {'path': 'output\\F_0101_13y1m_1_segment_154.mp3',
#   'utterance': 'quite',
#   'class': 0},
#  {'path': 'output\\F_0101_13y1m_1_segment_155.mp3',
#   'utterance': 'good',
#   'class': 0},
#  {'path': 'output\\F_0101_13y1m_1_segment_156.mp3',
#   'utterance': 'AND',
#   'class': 4},
#  {'path': 'output\\F_0101_13y1m_1_segment_157.mp3',
#   'utterance': 'AND',
#   'class': 4},
#  {'path': 'output\\F_0101_13y1m_1_segment_158.mp3',
#   'utterance': 'food',
#   'class': 0},
#  {'path': 'output\\F_0101_13y1m_1_segment_159.mp3',
#   'utterance': 'tasted',
#   'class': 0},
#  {'path': 'output\\F_0101_13y1m_1_segment_16.mp3',
#   'utterance': 'UM',
#   'class': 1},
#  {'path': 'output\\F_0101_13y1m_1_segment_160.mp3',
#   'utterance': 'nice',
#   'class': 0},
#  {'path': 'output\\F_0101_13y1m_1_segment_161.mp3',
#   'utterance': 'UM',
#   'class': 1},
#  {'path': 'output\\F_0101_13y1m_1_segment_162.mp3',
#   'utterance': 'UM',
#   'class': 1},
#  {'path': 'output\\F_0101_13y1m_1_segment_163.mp3',
#   'utterance': 'Then',
#   'class': 0},
#  {'path': 'output\\F_0101_13y1m_1_segment_164.mp3',
#   'utterance': 'we',
#   'class': 0},
#  {'path': 'output\\F_0101_13y1m_1_segment_165.mp3',
#   'utterance': 'came',
#   'class': 0},
#  {'path': 'output\\F_0101_13y1m_1_segment_166.mp3',
#   'utterance': 'back',
#   'class': 0},
#  {'path': 'output\\F_0101_13y1m_1_segment_167.mp3',
#   'utterance': 'from',
#   'class': 0},
#  {'path': 'output\\F_0101_13y1m_1_segment_168.mp3',
#   'utterance': 'that',
#   'class': 0},
#  {'path': 'output\\F_0101_13y1m_1_segment_169.mp3',
#   'utterance': 'and',
#   'class': 0},
#  {'path': 'output\\F_0101_13y1m_1_segment_17.mp3',
#   'utterance': 'black',
#   'class': 0},
#  {'path': 'output\\F_0101_13y1m_1_segment_170.mp3',
#   'utterance': 'we',
#   'class': 0},
#  {'path': 'output\\F_0101_13y1m_1_segment_171.mp3',
#   'utterance': 'had',
#   'class': 0},
#  {'path': 'output\\F_0101_13y1m_1_segment_172.mp3',
#   'utterance': 'a',
#   'class': 0},
#  {'path': 'output\\F_0101_13y1m_1_segment_173.mp3',
#   'utterance': 'S',
#   'class': 7},
#  {'path': 'output\\F_0101_13y1m_1_segment_174.mp3',
#   'utterance': 'MALL',
#   'class': 7},
#  {'path': 'output\\F_0101_13y1m_1_segment_175.mp3',
#   'utterance': 'tea',
#   'class': 0},
#  {'path': 'output\\F_0101_13y1m_1_segment_176.mp3',
#   'utterance': 'and',
#   'class': 0},
#  {'path': 'output\\F_0101_13y1m_1_segment_177.mp3',
#   'utterance': 'on',
#   'class': 0},
#  {'path': 'output\\F_0101_13y1m_1_segment_178.mp3',
#   'utterance': 'Boxing',
#   'class': 0},
#  {'path': 'output\\F_0101_13y1m_1_segment_179.mp3',
#   'utterance': 'Day',
#   'class': 0},
#  {'path': 'output\\F_0101_13y1m_1_segment_18.mp3',
#   'utterance': 'and',
#   'class': 0},
#  {'path': 'output\\F_0101_13y1m_1_segment_180.mp3',
#   'utterance': 'WE',
#   'class': 6},
#  {'path': 'output\\F_0101_13y1m_1_segment_181.mp3',
#   'utterance': 'MY',
#   'class': 6},
#  {'path': 'output\\F_0101_13y1m_1_segment_182.mp3',
#   'utterance': 'MUM',
#   'class': 6},
#  {'path': 'output\\F_0101_13y1m_1_segment_183.mp3',
#   'utterance': 'cooked',
#   'class': 0},
#  {'path': 'output\\F_0101_13y1m_1_segment_184.mp3',
#   'utterance': 'A',
#   'class': 4},
#  {'path': 'output\\F_0101_13y1m_1_segment_185.mp3',
#   'utterance': 'A',
#   'class': 4},
#  {'path': 'output\\F_0101_13y1m_1_segment_186.mp3',
#   'utterance': 'meal',
#   'class': 0},
#  {'path': 'output\\F_0101_13y1m_1_segment_187.mp3',
#   'utterance': 'then',
#   'class': 0},
#  {'path': 'output\\F_0101_13y1m_1_segment_188.mp3',
#   'utterance': 'So',
#   'class': 0},
#  {'path': 'output\\F_0101_13y1m_1_segment_189.mp3',
#   'utterance': 'she',
#   'class': 0},
#  {'path': 'output\\F_0101_13y1m_1_segment_19.mp3',
#   'utterance': 'white',
#   'class': 0},
#  {'path': 'output\\F_0101_13y1m_1_segment_190.mp3',
#   'utterance': "didn't",
#   'class': 0},
#  {'path': 'output\\F_0101_13y1m_1_segment_191.mp3',
#   'utterance': 'have',
#   'class': 0},
#  {'path': 'output\\F_0101_13y1m_1_segment_192.mp3',
#   'utterance': 'to',
#   'class': 0},
#  {'path': 'output\\F_0101_13y1m_1_segment_193.mp3',
#   'utterance': 'cook',
#   'class': 0},
#  {'path': 'output\\F_0101_13y1m_1_segment_194.mp3',
#   'utterance': 'a',
#   'class': 0},
#  {'path': 'output\\F_0101_13y1m_1_segment_195.mp3',
#   'utterance': 'meal',
#   'class': 0},
#  {'path': 'output\\F_0101_13y1m_1_segment_196.mp3',
#   'utterance': 'twice',
#   'class': 0},
#  {'path': 'output\\F_0101_13y1m_1_segment_197.mp3',
#   'utterance': 'UM',
#   'class': 1},
#  {'path': 'output\\F_0101_13y1m_1_segment_2.mp3',
#   'utterance': 'Christmas',
#   'class': 0},
#  {'path': 'output\\F_0101_13y1m_1_segment_20.mp3',
#   'utterance': 'ER',
#   'class': 1},
#  {'path': 'output\\F_0101_13y1m_1_segment_21.mp3',
#   'utterance': 'i',
#   'class': 0},
#  {'path': 'output\\F_0101_13y1m_1_segment_22.mp3',
#   'utterance': "didn't",
#   'class': 0},
#  {'path': 'output\\F_0101_13y1m_1_segment_23.mp3',
#   'utterance': 'get',
#   'class': 0},
#  {'path': 'output\\F_0101_13y1m_1_segment_24.mp3',
#   'utterance': 'that',
#   'class': 0},
#  {'path': 'output\\F_0101_13y1m_1_segment_25.mp3',
#   'utterance': 'many',
#   'class': 0},
#  {'path': 'output\\F_0101_13y1m_1_segment_26.mp3',
#   'utterance': 'books',
#   'class': 0},
#  {'path': 'output\\F_0101_13y1m_1_segment_27.mp3',
#   'utterance': 'this',
#   'class': 0},
#  {'path': 'output\\F_0101_13y1m_1_segment_28.mp3',
#   'utterance': 'year',
#   'class': 0},
#  {'path': 'output\\F_0101_13y1m_1_segment_29.mp3',
#   'utterance': 'but',
#   'class': 0},
#  {'path': 'output\\F_0101_13y1m_1_segment_3.mp3',
#   'utterance': 'i',
#   'class': 0},
#  {'path': 'output\\F_0101_13y1m_1_segment_30.mp3',
#   'utterance': 'UM',
#   'class': 1},
#  {'path': 'output\\F_0101_13y1m_1_segment_31.mp3',
#   'utterance': 'but',
#   'class': 0},
#  {'path': 'output\\F_0101_13y1m_1_segment_32.mp3',
#   'utterance': 'i',
#   'class': 0},
#  {'path': 'output\\F_0101_13y1m_1_segment_33.mp3',
#   'utterance': 'did',
#   'class': 0},
#  {'path': 'output\\F_0101_13y1m_1_segment_34.mp3',
#   'utterance': 'get',
#   'class': 0},
#  {'path': 'output\\F_0101_13y1m_1_segment_35.mp3',
#   'utterance': 'a',
#   'class': 0},
#  {'path': 'output\\F_0101_13y1m_1_segment_36.mp3',
#   'utterance': 'few',
#   'class': 0},
#  {'path': 'output\\F_0101_13y1m_1_segment_37.mp3',
#   'utterance': 'computer',
#   'class': 0},
#  {'path': 'output\\F_0101_13y1m_1_segment_38.mp3',
#   'utterance': 'games',
#   'class': 0},
#  {'path': 'output\\F_0101_13y1m_1_segment_39.mp3',
#   'utterance': 'and',
#   'class': 0},
#  {'path': 'output\\F_0101_13y1m_1_segment_4.mp3',
#   'utterance': 'got',
#   'class': 0},
#  {'path': 'output\\F_0101_13y1m_1_segment_40.mp3',
#   'utterance': 'a',
#   'class': 0},
#  {'path': 'output\\F_0101_13y1m_1_segment_41.mp3',
#   'utterance': 'computer',
#   'class': 0},
#  {'path': 'output\\F_0101_13y1m_1_segment_42.mp3',
#   'utterance': 'CONS',
#   'class': 7},
#  {'path': 'output\\F_0101_13y1m_1_segment_43.mp3',
#   'utterance': 'OLE',
#   'class': 7},
#  {'path': 'output\\F_0101_13y1m_1_segment_44.mp3',
#   'utterance': 'which',
#   'class': 0},
#  {'path': 'output\\F_0101_13y1m_1_segment_45.mp3',
#   'utterance': 'was',
#   'class': 0},
#  {'path': 'output\\F_0101_13y1m_1_segment_46.mp3',
#   'utterance': 'a',
#   'class': 0},
#  {'path': 'output\\F_0101_13y1m_1_segment_47.mp3',
#   'utterance': 'PLAY',
#   'class': 3},
#  {'path': 'output\\F_0101_13y1m_1_segment_48.mp3',
#   'utterance': 'PLAYSTATION',
#   'class': 3},
#  {'path': 'output\\F_0101_13y1m_1_segment_49.mp3',
#   'utterance': 'two',
#   'class': 0},
#  {'path': 'output\\F_0101_13y1m_1_segment_5.mp3',
#   'utterance': 'that',
#   'class': 0},
#  {'path': 'output\\F_0101_13y1m_1_segment_50.mp3',
#   'utterance': 'UM',
#   'class': 1},
#  {'path': 'output\\F_0101_13y1m_1_segment_51.mp3',
#   'utterance': 'and',
#   'class': 0},
#  {'path': 'output\\F_0101_13y1m_1_segment_52.mp3',
#   'utterance': "that's",
#   'class': 0},
#  {'path': 'output\\F_0101_13y1m_1_segment_53.mp3',
#   'utterance': 'quite',
#   'class': 0},
#  {'path': 'output\\F_0101_13y1m_1_segment_54.mp3',
#   'utterance': 'good',
#   'class': 0},
#  {'path': 'output\\F_0101_13y1m_1_segment_55.mp3',
#   'utterance': 'to',
#   'class': 0},
#  {'path': 'output\\F_0101_13y1m_1_segment_56.mp3',
#   'utterance': 'play',
#   'class': 0},
#  {'path': 'output\\F_0101_13y1m_1_segment_57.mp3',
#   'utterance': 'on',
#   'class': 0},
#  {'path': 'output\\F_0101_13y1m_1_segment_58.mp3',
#   'utterance': 'ERM',
#   'class': 1},
#  {'path': 'output\\F_0101_13y1m_1_segment_59.mp3',
#   'utterance': 'i',
#   'class': 0},
#  {'path': 'output\\F_0101_13y1m_1_segment_6.mp3',
#   'utterance': 'bear',
#   'class': 0},
#  {'path': 'output\\F_0101_13y1m_1_segment_60.mp3',
#   'utterance': 'got',
#   'class': 0},
#  {'path': 'output\\F_0101_13y1m_1_segment_61.mp3',
#   'utterance': 'a',
#   'class': 0},
#  {'path': 'output\\F_0101_13y1m_1_segment_62.mp3',
#   'utterance': 'marbling',
#   'class': 0},
#  {'path': 'output\\F_0101_13y1m_1_segment_63.mp3',
#   'utterance': 'kit',
#   'class': 0},
#  {'path': 'output\\F_0101_13y1m_1_segment_64.mp3',
#   'utterance': 'so',
#   'class': 0},
#  {'path': 'output\\F_0101_13y1m_1_segment_65.mp3',
#   'utterance': 'you',
#   'class': 0},
#  {'path': 'output\\F_0101_13y1m_1_segment_66.mp3',
#   'utterance': 'can',
#   'class': 0},
#  {'path': 'output\\F_0101_13y1m_1_segment_67.mp3',
#   'utterance': 'do',
#   'class': 0},
#  {'path': 'output\\F_0101_13y1m_1_segment_68.mp3',
#   'utterance': 'your',
#   'class': 0},
#  {'path': 'output\\F_0101_13y1m_1_segment_69.mp3',
#   'utterance': 'ouwn',
#   'class': 0},
#  {'path': 'output\\F_0101_13y1m_1_segment_7.mp3',
#   'utterance': 'AND',
#   'class': 4},
#  {'path': 'output\\F_0101_13y1m_1_segment_70.mp3',
#   'utterance': 'marbling',
#   'class': 0},
#  {'path': 'output\\F_0101_13y1m_1_segment_71.mp3',
#   'utterance': 'things',
#   'class': 0},
#  {'path': 'output\\F_0101_13y1m_1_segment_72.mp3',
#   'utterance': 'UM',
#   'class': 1},
#  {'path': 'output\\F_0101_13y1m_1_segment_73.mp3',
#   'utterance': 'and',
#   'class': 0},
#  {'path': 'output\\F_0101_13y1m_1_segment_74.mp3',
#   'utterance': 'i',
#   'class': 0},
#  {'path': 'output\\F_0101_13y1m_1_segment_75.mp3',
#   'utterance': 'got',
#   'class': 0},
#  {'path': 'output\\F_0101_13y1m_1_segment_76.mp3',
#   'utterance': 'other',
#   'class': 0},
#  {'path': 'output\\F_0101_13y1m_1_segment_77.mp3',
#   'utterance': 'small',
#   'class': 0},
#  {'path': 'output\\F_0101_13y1m_1_segment_78.mp3',
#   'utterance': 'bits',
#   'class': 0},
#  {'path': 'output\\F_0101_13y1m_1_segment_79.mp3',
#   'utterance': 'and',
#   'class': 0},
#  {'path': 'output\\F_0101_13y1m_1_segment_8.mp3',
#   'utterance': 'AND',
#   'class': 4},
#  {'path': 'output\\F_0101_13y1m_1_segment_80.mp3',
#   'utterance': 'pieces',
#   'class': 0},
#  {'path': 'output\\F_0101_13y1m_1_segment_81.mp3',
#   'utterance': 'for',
#   'class': 0},
#  {'path': 'output\\F_0101_13y1m_1_segment_82.mp3',
#   'utterance': 'my',
#   'class': 0},
#  {'path': 'output\\F_0101_13y1m_1_segment_83.mp3',
#   'utterance': 'cats',
#   'class': 0},
#  {'path': 'output\\F_0101_13y1m_1_segment_84.mp3',
#   'utterance': 'i',
#   'class': 0},
#  {'path': 'output\\F_0101_13y1m_1_segment_85.mp3',
#   'utterance': 'bought',
#   'class': 0},
#  {'path': 'output\\F_0101_13y1m_1_segment_86.mp3',
#   'utterance': 'them',
#   'class': 0},
#  {'path': 'output\\F_0101_13y1m_1_segment_87.mp3',
#   'utterance': 'THISSSSSS',
#   'class': 4},
#  {'path': 'output\\F_0101_13y1m_1_segment_88.mp3',
#   'utterance': 'THIS',
#   'class': 4},
#  {'path': 'output\\F_0101_13y1m_1_segment_89.mp3',
#   'utterance': 'thing',
#   'class': 0},
#  {'path': 'output\\F_0101_13y1m_1_segment_9.mp3',
#   'utterance': 'also',
#   'class': 0},
#  {'path': 'output\\F_0101_13y1m_1_segment_90.mp3',
#   'utterance': 'that',
#   'class': 0},
#  {'path': 'output\\F_0101_13y1m_1_segment_91.mp3',
#   'utterance': 'L',
#   'class': 2},
#  {'path': 'output\\F_0101_13y1m_1_segment_92.mp3',
#   'utterance': 'LOOKS',
#   'class': 2},
#  {'path': 'output\\F_0101_13y1m_1_segment_93.mp3',
#   'utterance': 'like',
#   'class': 0},
#  {'path': 'output\\F_0101_13y1m_1_segment_94.mp3',
#   'utterance': 'a',
#   'class': 0},
#  {'path': 'output\\F_0101_13y1m_1_segment_95.mp3',
#   'utterance': 'slice',
#   'class': 0},
#  {'path': 'output\\F_0101_13y1m_1_segment_96.mp3',
#   'utterance': 'of',
#   'class': 0},
#  {'path': 'output\\F_0101_13y1m_1_segment_97.mp3',
#   'utterance': 'cheese',
#   'class': 0},
#  {'path': 'output\\F_0101_13y1m_1_segment_98.mp3',
#   'utterance': 'with',
#   'class': 0},
#  {'path': 'output\\F_0101_13y1m_1_segment_99.mp3',
#   'utterance': 'H',
#   'class': 2},
#  {'path': 'output\\M_0028_15y11m_1_segment_0.mp3',
#   'utterance': "I've",
#   'class': 0},
#  {'path': 'output\\M_0028_15y11m_1_segment_1.mp3',
#   'utterance': 'supported',
#   'class': 0},
#  {'path': 'output\\M_0028_15y11m_1_segment_10.mp3',
#   'utterance': 'them',
#   'class': 0},
#  {'path': 'output\\M_0028_15y11m_1_segment_100.mp3',
#   'utterance': 'i',
#   'class': 0},
#  {'path': 'output\\M_0028_15y11m_1_segment_101.mp3',
#   'utterance': 'chose',
#   'class': 0},
#  {'path': 'output\\M_0028_15y11m_1_segment_102.mp3',
#   'utterance': 'Business',
#   'class': 0},
#  {'path': 'output\\M_0028_15y11m_1_segment_103.mp3',
#   'utterance': 'Studies',
#   'class': 0},
#  {'path': 'output\\M_0028_15y11m_1_segment_104.mp3',
#   'utterance': 'Geography',
#   'class': 0},
#  {'path': 'output\\M_0028_15y11m_1_segment_105.mp3',
#   'utterance': 'double',
#   'class': 0},
#  {'path': 'output\\M_0028_15y11m_1_segment_106.mp3',
#   'utterance': 'science',
#   'class': 0},
#  {'path': 'output\\M_0028_15y11m_1_segment_107.mp3',
#   'utterance': 'English',
#   'class': 0},
#  {'path': 'output\\M_0028_15y11m_1_segment_108.mp3',
#   'utterance': 'Maths',
#   'class': 0},
#  {'path': 'output\\M_0028_15y11m_1_segment_109.mp3',
#   'utterance': 'ER',
#   'class': 1},
#  {'path': 'output\\M_0028_15y11m_1_segment_11.mp3',
#   'utterance': 'in',
#   'class': 0},
#  {'path': 'output\\M_0028_15y11m_1_segment_110.mp3',
#   'utterance': 'French',
#   'class': 0},
#  {'path': 'output\\M_0028_15y11m_1_segment_111.mp3',
#   'utterance': 'English',
#   'class': 0},
#  {'path': 'output\\M_0028_15y11m_1_segment_112.mp3',
#   'utterance': 'Literature',
#   'class': 0},
#  {'path': 'output\\M_0028_15y11m_1_segment_113.mp3',
#   'utterance': 'and',
#   'class': 0},
#  {'path': 'output\\M_0028_15y11m_1_segment_114.mp3',
#   'utterance': 'language',
#   'class': 0},
#  {'path': 'output\\M_0028_15y11m_1_segment_115.mp3',
#   'utterance': 'ERM',
#   'class': 1},
#  {'path': 'output\\M_0028_15y11m_1_segment_116.mp3',
#   'utterance': "I'm",
#   'class': 0},
#  {'path': 'output\\M_0028_15y11m_1_segment_117.mp3',
#   'utterance': 'doing',
#   'class': 0},
#  {'path': 'output\\M_0028_15y11m_1_segment_118.mp3',
#   'utterance': 'all',
#   'class': 0},
#  {'path': 'output\\M_0028_15y11m_1_segment_119.mp3',
#   'utterance': 'high',
#   'class': 0},
#  {'path': 'output\\M_0028_15y11m_1_segment_12.mp3',
#   'utterance': '1990',
#   'class': 0},
#  {'path': 'output\\M_0028_15y11m_1_segment_120.mp3',
#   'utterance': 'papers',
#   'class': 0},
#  {'path': 'output\\M_0028_15y11m_1_segment_121.mp3',
#   'utterance': 'in',
#   'class': 0},
#  {'path': 'output\\M_0028_15y11m_1_segment_122.mp3',
#   'utterance': 'everything',
#   'class': 0},
#  {'path': 'output\\M_0028_15y11m_1_segment_123.mp3',
#   'utterance': 'ER',
#   'class': 1},
#  {'path': 'output\\M_0028_15y11m_1_segment_124.mp3',
#   'utterance': 'so',
#   'class': 0},
#  {'path': 'output\\M_0028_15y11m_1_segment_125.mp3',
#   'utterance': 'far',
#   'class': 0},
#  {'path': 'output\\M_0028_15y11m_1_segment_126.mp3',
#   'utterance': "I've",
#   'class': 0},
#  {'path': 'output\\M_0028_15y11m_1_segment_127.mp3',
#   'utterance': 'had',
#   'class': 0},
#  {'path': 'output\\M_0028_15y11m_1_segment_128.mp3',
#   'utterance': 'my',
#   'class': 0},
#  {'path': 'output\\M_0028_15y11m_1_segment_129.mp3',
#   'utterance': 'Geography',
#   'class': 0},
#  {'path': 'output\\M_0028_15y11m_1_segment_13.mp3',
#   'utterance': 'when',
#   'class': 0},
#  {'path': 'output\\M_0028_15y11m_1_segment_130.mp3',
#   'utterance': 'that',
#   'class': 0},
#  {'path': 'output\\M_0028_15y11m_1_segment_131.mp3',
#   'utterance': 'went',
#   'class': 0},
#  {'path': 'output\\M_0028_15y11m_1_segment_132.mp3',
#   'utterance': 'really',
#   'class': 0},
#  {'path': 'output\\M_0028_15y11m_1_segment_133.mp3',
#   'utterance': 'well',
#   'class': 0},
#  {'path': 'output\\M_0028_15y11m_1_segment_134.mp3',
#   'utterance': 'found',
#   'class': 0},
#  {'path': 'output\\M_0028_15y11m_1_segment_135.mp3',
#   'utterance': 'that',
#   'class': 0},
#  {'path': 'output\\M_0028_15y11m_1_segment_136.mp3',
#   'utterance': 'really',
#   'class': 0},
#  {'path': 'output\\M_0028_15y11m_1_segment_137.mp3',
#   'utterance': 'easy',
#   'class': 0},
#  {'path': 'output\\M_0028_15y11m_1_segment_138.mp3',
#   'utterance': 'ER',
#   'class': 1},
#  {'path': 'output\\M_0028_15y11m_1_segment_139.mp3',
#   'utterance': 'my',
#   'class': 0},
#  {'path': 'output\\M_0028_15y11m_1_segment_14.mp3',
#   'utterance': 'my',
#   'class': 0},
#  {'path': 'output\\M_0028_15y11m_1_segment_140.mp3',
#   'utterance': 'r.e.',
#   'class': 0},
#  {'path': 'output\\M_0028_15y11m_1_segment_141.mp3',
#   'utterance': 'ER',
#   'class': 1},
#  {'path': 'output\\M_0028_15y11m_1_segment_142.mp3',
#   'utterance': "didn't",
#   'class': 0},
#  {'path': 'output\\M_0028_15y11m_1_segment_143.mp3',
#   'utterance': 'do',
#   'class': 0},
#  {'path': 'output\\M_0028_15y11m_1_segment_144.mp3',
#   'utterance': 'too',
#   'class': 0},
#  {'path': 'output\\M_0028_15y11m_1_segment_145.mp3',
#   'utterance': 'well',
#   'class': 0},
#  {'path': 'output\\M_0028_15y11m_1_segment_146.mp3',
#   'utterance': 'in',
#   'class': 0},
#  {'path': 'output\\M_0028_15y11m_1_segment_147.mp3',
#   'utterance': 'that',
#   'class': 0},
#  {'path': 'output\\M_0028_15y11m_1_segment_148.mp3',
#   'utterance': 'because',
#   'class': 0},
#  {'path': 'output\\M_0028_15y11m_1_segment_149.mp3',
#   'utterance': "couldn't",
#   'class': 0},
#  {'path': 'output\\M_0028_15y11m_1_segment_15.mp3',
#   'utterance': 'uncle',
#   'class': 0},
#  {'path': 'output\\M_0028_15y11m_1_segment_150.mp3',
#   'utterance': 'really',
#   'class': 0},
#  {'path': 'output\\M_0028_15y11m_1_segment_151.mp3',
#   'utterance': 'learn',
#   'class': 0},
#  {'path': 'output\\M_0028_15y11m_1_segment_152.mp3',
#   'utterance': 'nothing',
#   'class': 0},
#  {'path': 'output\\M_0028_15y11m_1_segment_153.mp3',
#   'utterance': 'My',
#   'class': 0},
#  {'path': 'output\\M_0028_15y11m_1_segment_154.mp3',
#   'utterance': 'MATHSSSSSSS',
#   'class': 7},
#  {'path': 'output\\M_0028_15y11m_1_segment_155.mp3',
#   'utterance': 'that',
#   'class': 0},
#  {'path': 'output\\M_0028_15y11m_1_segment_156.mp3',
#   'utterance': 'was',
#   'class': 0},
#  {'path': 'output\\M_0028_15y11m_1_segment_157.mp3',
#   'utterance': 'really',
#   'class': 0},
#  {'path': 'output\\M_0028_15y11m_1_segment_158.mp3',
#   'utterance': 'hard',
#   'class': 0},
#  {'path': 'output\\M_0028_15y11m_1_segment_159.mp3',
#   'utterance': 'all',
#   'class': 0},
#  {'path': 'output\\M_0028_15y11m_1_segment_16.mp3',
#   'utterance': 'died',
#   'class': 0},
#  {'path': 'output\\M_0028_15y11m_1_segment_160.mp3',
#   'utterance': 'the',
#   'class': 0},
#  {'path': 'output\\M_0028_15y11m_1_segment_161.mp3',
#   'utterance': 'things',
#   'class': 0},
#  {'path': 'output\\M_0028_15y11m_1_segment_162.mp3',
#   'utterance': 'i',
#   'class': 0},
#  {'path': 'output\\M_0028_15y11m_1_segment_163.mp3',
#   'utterance': 'studied',
#   'class': 0},
#  {'path': 'output\\M_0028_15y11m_1_segment_164.mp3',
#   'utterance': 'on',
#   'class': 0},
#  {'path': 'output\\M_0028_15y11m_1_segment_165.mp3',
#   'utterance': "didn't",
#   'class': 0},
#  {'path': 'output\\M_0028_15y11m_1_segment_166.mp3',
#   'utterance': 'turn',
#   'class': 0},
#  {'path': 'output\\M_0028_15y11m_1_segment_167.mp3',
#   'utterance': 'up',
#   'class': 0},
#  {'path': 'output\\M_0028_15y11m_1_segment_168.mp3',
#   'utterance': "didn't",
#   'class': 0},
#  {'path': 'output\\M_0028_15y11m_1_segment_169.mp3',
#   'utterance': 'come',
#   'class': 0},
#  {'path': 'output\\M_0028_15y11m_1_segment_17.mp3',
#   'utterance': 'When',
#   'class': 0},
#  {'path': 'output\\M_0028_15y11m_1_segment_170.mp3',
#   'utterance': 'up',
#   'class': 0},
#  {'path': 'output\\M_0028_15y11m_1_segment_171.mp3',
#   'utterance': 'And',
#   'class': 0},
#  {'path': 'output\\M_0028_15y11m_1_segment_172.mp3',
#   'utterance': 'then',
#   'class': 0},
#  {'path': 'output\\M_0028_15y11m_1_segment_173.mp3',
#   'utterance': 'on',
#   'class': 0},
#  {'path': 'output\\M_0028_15y11m_1_segment_174.mp3',
#   'utterance': 'my',
#   'class': 0},
#  {'path': 'output\\M_0028_15y11m_1_segment_175.mp3',
#   'utterance': 'Technology',
#   'class': 0},
#  {'path': 'output\\M_0028_15y11m_1_segment_176.mp3',
#   'utterance': 'i',
#   'class': 0},
#  {'path': 'output\\M_0028_15y11m_1_segment_177.mp3',
#   'utterance': 'learned',
#   'class': 0},
#  {'path': 'output\\M_0028_15y11m_1_segment_178.mp3',
#   'utterance': 'everything',
#   'class': 0},
#  {'path': 'output\\M_0028_15y11m_1_segment_179.mp3',
#   'utterance': 'that',
#   'class': 0},
#  {'path': 'output\\M_0028_15y11m_1_segment_18.mp3',
#   'utterance': 'i',
#   'class': 0},
#  {'path': 'output\\M_0028_15y11m_1_segment_180.mp3',
#   'utterance': 'was',
#   'class': 0},
#  {'path': 'output\\M_0028_15y11m_1_segment_181.mp3',
#   'utterance': 'really',
#   'class': 0},
#  {'path': 'output\\M_0028_15y11m_1_segment_182.mp3',
#   'utterance': 'hard',
#   'class': 0},
#  {'path': 'output\\M_0028_15y11m_1_segment_183.mp3',
#   'utterance': 'i',
#   'class': 0},
#  {'path': 'output\\M_0028_15y11m_1_segment_184.mp3',
#   'utterance': "didn't",
#   'class': 0},
#  {'path': 'output\\M_0028_15y11m_1_segment_185.mp3',
#   'utterance': 'really',
#   'class': 0},
#  {'path': 'output\\M_0028_15y11m_1_segment_186.mp3',
#   'utterance': 'understand',
#   'class': 0},
#  {'path': 'output\\M_0028_15y11m_1_segment_187.mp3',
#   'utterance': 'all',
#   'class': 0},
#  {'path': 'output\\M_0028_15y11m_1_segment_188.mp3',
#   'utterance': 'of',
#   'class': 0},
#  {'path': 'output\\M_0028_15y11m_1_segment_189.mp3',
#   'utterance': 'it',
#   'class': 0},
#  {'path': 'output\\M_0028_15y11m_1_segment_19.mp3',
#   'utterance': 'was',
#   'class': 0},
#  {'path': 'output\\M_0028_15y11m_1_segment_190.mp3',
#   'utterance': 'And',
#   'class': 0},
#  {'path': 'output\\M_0028_15y11m_1_segment_191.mp3',
#   'utterance': 'tomorrow',
#   'class': 0},
#  {'path': 'output\\M_0028_15y11m_1_segment_192.mp3',
#   'utterance': 'i',
#   'class': 0},
#  {'path': 'output\\M_0028_15y11m_1_segment_193.mp3',
#   'utterance': 'have',
#   'class': 0},
#  {'path': 'output\\M_0028_15y11m_1_segment_194.mp3',
#   'utterance': 'Maths',
#   'class': 0},
#  {'path': 'output\\M_0028_15y11m_1_segment_195.mp3',
#   'utterance': 'and',
#   'class': 0},
#  {'path': 'output\\M_0028_15y11m_1_segment_196.mp3',
#   'utterance': 'Science',
#   'class': 0},
#  {'path': 'output\\M_0028_15y11m_1_segment_197.mp3',
#   'utterance': 'again',
#   'class': 0},
#  {'path': 'output\\M_0028_15y11m_1_segment_198.mp3',
#   'utterance': 'SAME',
#   'class': 4},
#  {'path': 'output\\M_0028_15y11m_1_segment_199.mp3',
#   'utterance': 'SAME',
#   'class': 4},
#  {'path': 'output\\M_0028_15y11m_1_segment_2.mp3',
#   'utterance': 'Aston',
#   'class': 0},
#  {'path': 'output\\M_0028_15y11m_1_segment_20.mp3',
#   'utterance': 'going',
#   'class': 0},
#  {'path': 'output\\M_0028_15y11m_1_segment_200.mp3',
#   'utterance': 'day',
#   'class': 0},
#  {'path': 'output\\M_0028_15y11m_1_segment_201.mp3',
#   'utterance': 'as',
#   'class': 0},
#  {'path': 'output\\M_0028_15y11m_1_segment_202.mp3',
#   'utterance': 'i',
#   'class': 0},
#  {'path': 'output\\M_0028_15y11m_1_segment_203.mp3',
#   'utterance': 'had',
#   'class': 0},
#  {'path': 'output\\M_0028_15y11m_1_segment_204.mp3',
#   'utterance': 'on',
#   'class': 0},
#  {'path': 'output\\M_0028_15y11m_1_segment_205.mp3',
#   'utterance': 'Friday',
#   'class': 0},
#  {'path': 'output\\M_0028_15y11m_1_segment_206.mp3',
#   'utterance': 'had',
#   'class': 0},
#  {'path': 'output\\M_0028_15y11m_1_segment_207.mp3',
#   'utterance': 'Maths',
#   'class': 0},
#  {'path': 'output\\M_0028_15y11m_1_segment_208.mp3',
#   'utterance': 'and',
#   'class': 0},
#  {'path': 'output\\M_0028_15y11m_1_segment_209.mp3',
#   'utterance': 'Science',
#   'class': 0},
#  {'path': 'output\\M_0028_15y11m_1_segment_21.mp3',
#   'utterance': 'through',
#   'class': 0},
#  {'path': 'output\\M_0028_15y11m_1_segment_210.mp3',
#   'utterance': 'then',
#   'class': 0},
#  {'path': 'output\\M_0028_15y11m_1_segment_211.mp3',
#   'utterance': 'Science',
#   'class': 0},
#  {'path': 'output\\M_0028_15y11m_1_segment_212.mp3',
#   'utterance': 'i',
#   'class': 0},
#  {'path': 'output\\M_0028_15y11m_1_segment_213.mp3',
#   'utterance': 'found',
#   'class': 0},
#  {'path': 'output\\M_0028_15y11m_1_segment_214.mp3',
#   'utterance': 'that',
#   'class': 0},
#  {'path': 'output\\M_0028_15y11m_1_segment_215.mp3',
#   'utterance': 'really',
#   'class': 0},
#  {'path': 'output\\M_0028_15y11m_1_segment_216.mp3',
#   'utterance': 'easy',
#   'class': 0},
#  {'path': 'output\\M_0028_15y11m_1_segment_217.mp3',
#   'utterance': 'all',
#   'class': 0},
#  {'path': 'output\\M_0028_15y11m_1_segment_218.mp3',
#   'utterance': 'multiple',
#   'class': 0},
#  {'path': 'output\\M_0028_15y11m_1_segment_219.mp3',
#   'utterance': 'choices',
#   'class': 0},
#  {'path': 'output\\M_0028_15y11m_1_segment_22.mp3',
#   'utterance': 'his',
#   'class': 0},
#  {'path': 'output\\M_0028_15y11m_1_segment_220.mp3',
#   'utterance': 'So',
#   'class': 0},
#  {'path': 'output\\M_0028_15y11m_1_segment_221.mp3',
#   'utterance': 'hopefully',
#   'class': 0},
#  {'path': 'output\\M_0028_15y11m_1_segment_222.mp3',
#   'utterance': "I'll",
#   'class': 0},
#  {'path': 'output\\M_0028_15y11m_1_segment_223.mp3',
#   'utterance': 'do',
#   'class': 0},
#  {'path': 'output\\M_0028_15y11m_1_segment_224.mp3',
#   'utterance': 'well',
#   'class': 0},
#  {'path': 'output\\M_0028_15y11m_1_segment_225.mp3',
#   'utterance': 'and',
#   'class': 0},
#  {'path': 'output\\M_0028_15y11m_1_segment_226.mp3',
#   'utterance': 'just',
#   'class': 0},
#  {'path': 'output\\M_0028_15y11m_1_segment_227.mp3',
#   'utterance': 'get',
#   'class': 0},
#  {'path': 'output\\M_0028_15y11m_1_segment_228.mp3',
#   'utterance': 'good',
#   'class': 0},
#  {'path': 'output\\M_0028_15y11m_1_segment_229.mp3',
#   'utterance': 'mock',
#   'class': 0},
#  {'path': 'output\\M_0028_15y11m_1_segment_23.mp3',
#   'utterance': 'house',
#   'class': 0},
#  {'path': 'output\\M_0028_15y11m_1_segment_230.mp3',
#   'utterance': 'results',
#   'class': 0},
#  {'path': 'output\\M_0028_15y11m_1_segment_24.mp3',
#   'utterance': 'i',
#   'class': 0},
#  {'path': 'output\\M_0028_15y11m_1_segment_25.mp3',
#   'utterance': 'found',
#   'class': 0},
#  {'path': 'output\\M_0028_15y11m_1_segment_26.mp3',
#   'utterance': 'a',
#   'class': 0},
#  {'path': 'output\\M_0028_15y11m_1_segment_27.mp3',
#   'utterance': 'couple',
#   'class': 0},
#  {'path': 'output\\M_0028_15y11m_1_segment_28.mp3',
#   'utterance': 'of',
#   'class': 0},
#  {'path': 'output\\M_0028_15y11m_1_segment_29.mp3',
#   'utterance': 'badges',
#   'class': 0},
#  {'path': 'output\\M_0028_15y11m_1_segment_3.mp3',
#   'utterance': 'VILLA',
#   'class': 4},
#  {'path': 'output\\M_0028_15y11m_1_segment_30.mp3',
#   'utterance': 'with',
#   'class': 0},
#  {'path': 'output\\M_0028_15y11m_1_segment_31.mp3',
#   'utterance': 'Aston',
#   'class': 0},
#  {'path': 'output\\M_0028_15y11m_1_segment_32.mp3',
#   'utterance': 'Villa',
#   'class': 0},
#  {'path': 'output\\M_0028_15y11m_1_segment_33.mp3',
#   'utterance': 'on',
#   'class': 0},
#  {'path': 'output\\M_0028_15y11m_1_segment_34.mp3',
#   'utterance': 'and',
#   'class': 0},
#  {'path': 'output\\M_0028_15y11m_1_segment_35.mp3',
#   'utterance': 'some',
#   'class': 0},
#  {'path': 'output\\M_0028_15y11m_1_segment_36.mp3',
#   'utterance': 'memorabilia',
#   'class': 0},
#  {'path': 'output\\M_0028_15y11m_1_segment_37.mp3',
#   'utterance': 'Since',
#   'class': 0},
#  {'path': 'output\\M_0028_15y11m_1_segment_38.mp3',
#   'utterance': 'then',
#   'class': 0},
#  {'path': 'output\\M_0028_15y11m_1_segment_39.mp3',
#   'utterance': "I've",
#   'class': 0},
#  {'path': 'output\\M_0028_15y11m_1_segment_4.mp3',
#   'utterance': 'VILLA',
#   'class': 4},
#  {'path': 'output\\M_0028_15y11m_1_segment_40.mp3',
#   'utterance': 'supported',
#   'class': 0},
#  {'path': 'output\\M_0028_15y11m_1_segment_41.mp3',
#   'utterance': 'them',
#   'class': 0},
#  {'path': 'output\\M_0028_15y11m_1_segment_42.mp3',
#   'utterance': 'ER',
#   'class': 1},
#  {'path': 'output\\M_0028_15y11m_1_segment_43.mp3',
#   'utterance': "I've",
#   'class': 0},
#  {'path': 'output\\M_0028_15y11m_1_segment_44.mp3',
#   'utterance': 'supported',
#   'class': 0},
#  {'path': 'output\\M_0028_15y11m_1_segment_45.mp3',
#   'utterance': 'them',
#   'class': 0},
#  {'path': 'output\\M_0028_15y11m_1_segment_46.mp3',
#   'utterance': 'through',
#   'class': 0},
#  {'path': 'output\\M_0028_15y11m_1_segment_47.mp3',
#   'utterance': 'thick',
#   'class': 0},
#  {'path': 'output\\M_0028_15y11m_1_segment_48.mp3',
#   'utterance': 'and',
#   'class': 0},
#  {'path': 'output\\M_0028_15y11m_1_segment_49.mp3',
#   'utterance': 'thin',
#   'class': 0},
#  {'path': 'output\\M_0028_15y11m_1_segment_5.mp3',
#   'utterance': 'for',
#   'class': 0},
#  {'path': 'output\\M_0028_15y11m_1_segment_50.mp3',
#   'utterance': 'last',
#   'class': 0},
#  {'path': 'output\\M_0028_15y11m_1_segment_51.mp3',
#   'utterance': 'couple',
#   'class': 0},
#  {'path': 'output\\M_0028_15y11m_1_segment_52.mp3',
#   'utterance': 'of',
#   'class': 0},
#  {'path': 'output\\M_0028_15y11m_1_segment_53.mp3',
#   'utterance': 'seasons',
#   'class': 0},
#  {'path': 'output\\M_0028_15y11m_1_segment_54.mp3',
#   'utterance': 'have',
#   'class': 0},
#  {'path': 'output\\M_0028_15y11m_1_segment_55.mp3',
#   'utterance': 'been',
#   'class': 0},
#  {'path': 'output\\M_0028_15y11m_1_segment_56.mp3',
#   'utterance': 'bad',
#   'class': 0},
#  {'path': 'output\\M_0028_15y11m_1_segment_57.mp3',
#   'utterance': 'this',
#   'class': 0},
#  {'path': 'output\\M_0028_15y11m_1_segment_58.mp3',
#   'utterance': 'season',
#   'class': 0},
#  {'path': 'output\\M_0028_15y11m_1_segment_59.mp3',
#   'utterance': 'doing',
#   'class': 0},
#  {'path': 'output\\M_0028_15y11m_1_segment_6.mp3',
#   'utterance': 'eight',
#   'class': 0},
#  {'path': 'output\\M_0028_15y11m_1_segment_60.mp3',
#   'utterance': 'really',
#   'class': 0},
#  {'path': 'output\\M_0028_15y11m_1_segment_61.mp3',
#   'utterance': 'well',
#   'class': 0},
#  {'path': 'output\\M_0028_15y11m_1_segment_62.mp3',
#   'utterance': "We've",
#   'class': 0},
#  {'path': 'output\\M_0028_15y11m_1_segment_63.mp3',
#   'utterance': 'bought',
#   'class': 0},
#  {'path': 'output\\M_0028_15y11m_1_segment_64.mp3',
#   'utterance': 'in',
#   'class': 0},
#  {'path': 'output\\M_0028_15y11m_1_segment_65.mp3',
#   'utterance': 'England',
#   'class': 0},
#  {'path': 'output\\M_0028_15y11m_1_segment_66.mp3',
#   'utterance': 'stars',
#   'class': 0},
#  {'path': 'output\\M_0028_15y11m_1_segment_67.mp3',
#   'utterance': "WE'VE",
#   'class': 7},
#  {'path': 'output\\M_0028_15y11m_1_segment_68.mp3',
#   'utterance': 'got',
#   'class': 0},
#  {'path': 'output\\M_0028_15y11m_1_segment_69.mp3',
#   'utterance': 'ten',
#   'class': 0},
#  {'path': 'output\\M_0028_15y11m_1_segment_7.mp3',
#   'utterance': 'years',
#   'class': 0},
#  {'path': 'output\\M_0028_15y11m_1_segment_70.mp3',
#   'utterance': 'players',
#   'class': 0},
#  {'path': 'output\\M_0028_15y11m_1_segment_71.mp3',
#   'utterance': 'from',
#   'class': 0},
#  {'path': 'output\\M_0028_15y11m_1_segment_72.mp3',
#   'utterance': 'England',
#   'class': 0},
#  {'path': 'output\\M_0028_15y11m_1_segment_73.mp3',
#   'utterance': 'in',
#   'class': 0},
#  {'path': 'output\\M_0028_15y11m_1_segment_74.mp3',
#   'utterance': 'our',
#   'class': 0},
#  {'path': 'output\\M_0028_15y11m_1_segment_75.mp3',
#   'utterance': 'squad',
#   'class': 0},
#  {'path': 'output\\M_0028_15y11m_1_segment_76.mp3',
#   'utterance': 'or',
#   'class': 0},
#  {'path': 'output\\M_0028_15y11m_1_segment_77.mp3',
#   'utterance': 'first',
#   'class': 0},
#  {'path': 'output\\M_0028_15y11m_1_segment_78.mp3',
#   'utterance': 'team',
#   'class': 0},
#  {'path': 'output\\M_0028_15y11m_1_segment_79.mp3',
#   'utterance': 'mainly',
#   'class': 0},
#  {'path': 'output\\M_0028_15y11m_1_segment_8.mp3',
#   'utterance': 'i',
#   'class': 0},
#  {'path': 'output\\M_0028_15y11m_1_segment_80.mp3',
#   'utterance': 'are',
#   'class': 0},
#  {'path': 'output\\M_0028_15y11m_1_segment_81.mp3',
#   'utterance': 'foreigners',
#   'class': 0},
#  {'path': 'output\\M_0028_15y11m_1_segment_82.mp3',
#   'utterance': 'Mark',
#   'class': 0},
#  {'path': 'output\\M_0028_15y11m_1_segment_83.mp3',
#   'utterance': 'Bosnich',
#   'class': 0},
#  {'path': 'output\\M_0028_15y11m_1_segment_84.mp3',
#   'utterance': "who's",
#   'class': 0},
#  {'path': 'output\\M_0028_15y11m_1_segment_85.mp3',
#   'utterance': 'going',
#   'class': 0},
#  {'path': 'output\\M_0028_15y11m_1_segment_86.mp3',
#   'utterance': 'to',
#   'class': 0},
#  {'path': 'output\\M_0028_15y11m_1_segment_87.mp3',
#   'utterance': 'go',
#   'class': 0},
#  {'path': 'output\\M_0028_15y11m_1_segment_88.mp3',
#   'utterance': 'UM',
#   'class': 1},
#  {'path': 'output\\M_0028_15y11m_1_segment_89.mp3',
#   'utterance': 'AT',
#   'class': 5},
#  {'path': 'output\\M_0028_15y11m_1_segment_9.mp3',
#   'utterance': 'supported',
#   'class': 0},
#  {'path': 'output\\M_0028_15y11m_1_segment_90.mp3',
#   'utterance': 'THE',
#   'class': 5},
#  {'path': 'output\\M_0028_15y11m_1_segment_91.mp3',
#   'utterance': 'AT',
#   'class': 5},
#  {'path': 'output\\M_0028_15y11m_1_segment_92.mp3',
#   'utterance': 'THE',
#   'class': 5},
#  {'path': 'output\\M_0028_15y11m_1_segment_93.mp3',
#   'utterance': 'moment',
#   'class': 0},
#  {'path': 'output\\M_0028_15y11m_1_segment_94.mp3',
#   'utterance': 'at',
#   'class': 0},
#  {'path': 'output\\M_0028_15y11m_1_segment_95.mp3',
#   'utterance': 'school',
#   'class': 0},
#  {'path': 'output\\M_0028_15y11m_1_segment_96.mp3',
#   'utterance': "I'm",
#   'class': 0},
#  {'path': 'output\\M_0028_15y11m_1_segment_97.mp3',
#   'utterance': 'doing',
#   'class': 0},
#  {'path': 'output\\M_0028_15y11m_1_segment_98.mp3',
#   'utterance': 'my',
#   'class': 0},
#  {'path': 'output\\M_0028_15y11m_1_segment_99.mp3',
#   'utterance': 'GCSEs',
#   'class': 0},
#  {'path': 'output\\M_0030_12y1m_1_segment_0.mp3',
#   'utterance': 'Most',
#   'class': 0},
#  {'path': 'output\\M_0030_12y1m_1_segment_1.mp3',
#   'utterance': 'of',
#   'class': 0},
#  {'path': 'output\\M_0030_12y1m_1_segment_10.mp3',
#   'utterance': 'UM',
#   'class': 1},
#  {'path': 'output\\M_0030_12y1m_1_segment_100.mp3',
#   'utterance': 'it',
#   'class': 0},
#  {'path': 'output\\M_0030_12y1m_1_segment_101.mp3',
#   'utterance': 'runs',
#   'class': 0},
#  {'path': 'output\\M_0030_12y1m_1_segment_102.mp3',
#   'utterance': 'that',
#   'class': 0},
#  {'path': 'output\\M_0030_12y1m_1_segment_103.mp3',
#   'utterance': 'i',
#   'class': 0},
#  {'path': 'output\\M_0030_12y1m_1_segment_104.mp3',
#   'utterance': 'think',
#   'class': 0},
#  {'path': 'output\\M_0030_12y1m_1_segment_105.mp3',
#   'utterance': "it's",
#   'class': 0},
#  {'path': 'output\\M_0030_12y1m_1_segment_106.mp3',
#   'utterance': 'because',
#   'class': 0},
#  {'path': 'output\\M_0030_12y1m_1_segment_107.mp3',
#   'utterance': 'of',
#   'class': 0},
#  {'path': 'output\\M_0030_12y1m_1_segment_108.mp3',
#   'utterance': 'memory',
#   'class': 0},
#  {'path': 'output\\M_0030_12y1m_1_segment_109.mp3',
#   'utterance': 'problems',
# ...
#   'class': 0},
#  {'path': 'output\\M_0030_12y1m_1_segment_6.mp3',
#   'utterance': 'is',
#   'class': 0},
#  {'path': 'output\\M_0030_12y1m_1_segment_60.mp3',
#   'utterance': 'all',
#   'class': 0},
#  {'path': 'output\\M_0030_12y1m_1_segment_61.mp3',
#   'utterance': 'the',
#   'class': 0},
#  {'path': 'output\\M_0030_12y1m_1_segment_62.mp3',
#   'utterance': 'add',
#   'class': 0},
#  {'path': 'output\\M_0030_12y1m_1_segment_63.mp3',
#   'utterance': 'ons',
#   'class': 0},
#  {'path': 'output\\M_0030_12y1m_1_segment_64.mp3',
#   'utterance': 'and',
#   'class': 0},
#  {'path': 'output\\M_0030_12y1m_1_segment_65.mp3',
#   'utterance': 'everything',
#   'class': 0},
#  {'path': 'output\\M_0030_12y1m_1_segment_66.mp3',
#   'utterance': "it's",
#   'class': 0},
#  {'path': 'output\\M_0030_12y1m_1_segment_67.mp3',
#   'utterance': 'really',
#   'class': 0},
#  {'path': 'output\\M_0030_12y1m_1_segment_68.mp3',
#   'utterance': 'a',
#   'class': 0},
#  {'path': 'output\\M_0030_12y1m_1_segment_69.mp3',
#   'utterance': 'very',
#   'class': 0},
#  {'path': 'output\\M_0030_12y1m_1_segment_7.mp3',
#   'utterance': 'in',
#   'class': 0},
#  {'path': 'output\\M_0030_12y1m_1_segment_70.mp3',
#   'utterance': 'U',
#   'class': 2},
#  {'path': 'output\\M_0030_12y1m_1_segment_71.mp3',
#   'utterance': 'USER',
#   'class': 2},
#  {'path': 'output\\M_0030_12y1m_1_segment_72.mp3',
#   'utterance': 'friendly',
#   'class': 0},
#  {'path': 'output\\M_0030_12y1m_1_segment_73.mp3',
#   'utterance': 'language',
#   'class': 0},
#  {'path': 'output\\M_0030_12y1m_1_segment_74.mp3',
#   'utterance': 'and',
#   'class': 0},
#  {'path': 'output\\M_0030_12y1m_1_segment_75.mp3',
#   'utterance': 'easy',
#   'class': 0},
#  {'path': 'output\\M_0030_12y1m_1_segment_76.mp3',
#   'utterance': 'to',
#   'class': 0},
#  {'path': 'output\\M_0030_12y1m_1_segment_77.mp3',
#   'utterance': 'use',
#   'class': 0},
#  {'path': 'output\\M_0030_12y1m_1_segment_78.mp3',
#   'utterance': 'UM',
#   'class': 1},
#  {'path': 'output\\M_0030_12y1m_1_segment_79.mp3',
#   'utterance': 'at',
#   'class': 0},
#  {'path': 'output\\M_0030_12y1m_1_segment_8.mp3',
#   'utterance': 'visual',
#   'class': 0},
#  {'path': 'output\\M_0030_12y1m_1_segment_80.mp3',
#   'utterance': 'home',
#   'class': 0},
#  {'path': 'output\\M_0030_12y1m_1_segment_81.mp3',
#   'utterance': "I've",
#   'class': 0},
#  {'path': 'output\\M_0030_12y1m_1_segment_82.mp3',
#   'utterance': 'actually',
#   'class': 0},
#  {'path': 'output\\M_0030_12y1m_1_segment_83.mp3',
#   'utterance': 'got',
#   'class': 0},
#  {'path': 'output\\M_0030_12y1m_1_segment_84.mp3',
#   'utterance': 'a',
#   'class': 0},
#  {'path': 'output\\M_0030_12y1m_1_segment_85.mp3',
#   'utterance': 'higher',
#   'class': 0},
#  {'path': 'output\\M_0030_12y1m_1_segment_86.mp3',
#   'utterance': 'version',
#   'class': 0},
#  {'path': 'output\\M_0030_12y1m_1_segment_87.mp3',
#   'utterance': 'of',
#   'class': 0},
#  {'path': 'output\\M_0030_12y1m_1_segment_88.mp3',
#   'utterance': 'visual',
#   'class': 0},
#  {'path': 'output\\M_0030_12y1m_1_segment_89.mp3',
#   'utterance': 'basic',
#   'class': 0},
#  {'path': 'output\\M_0030_12y1m_1_segment_9.mp3',
#   'utterance': 'basic',
#   'class': 0},
#  {'path': 'output\\M_0030_12y1m_1_segment_90.mp3',
#   'utterance': 'than',
#   'class': 0},
#  {'path': 'output\\M_0030_12y1m_1_segment_91.mp3',
#   'utterance': 'at',
#   'class': 0},
#  {'path': 'output\\M_0030_12y1m_1_segment_92.mp3',
#   'utterance': 'school',
#   'class': 0},
#  {'path': 'output\\M_0030_12y1m_1_segment_93.mp3',
#   'utterance': 'UM',
#   'class': 1},
#  {'path': 'output\\M_0030_12y1m_1_segment_94.mp3',
#   'utterance': 'but',
#   'class': 0},
#  {'path': 'output\\M_0030_12y1m_1_segment_95.mp3',
#   'utterance': 'the',
#   'class': 0},
#  {'path': 'output\\M_0030_12y1m_1_segment_96.mp3',
#   'utterance': 'computer',
#   'class': 0},
#  {'path': 'output\\M_0030_12y1m_1_segment_97.mp3',
#   'utterance': 'sometimes',
#   'class': 0},
#  {'path': 'output\\M_0030_12y1m_1_segment_98.mp3',
#   'utterance': 'crashes',
#   'class': 0},
#  {'path': 'output\\M_0030_12y1m_1_segment_99.mp3',
#   'utterance': 'when',
#   'class': 0},
#  {'path': 'output\\M_0030_17y9m_1_segment_0.mp3',
#   'utterance': 'Right',
#   'class': 0},
#  {'path': 'output\\M_0030_17y9m_1_segment_1.mp3',
#   'utterance': "I'm",
#   'class': 0},
#  {'path': 'output\\M_0030_17y9m_1_segment_10.mp3',
#   'utterance': 'UM',
#   'class': 1},
#  {'path': 'output\\M_0030_17y9m_1_segment_100.mp3',
#   'utterance': 'all',
#   'class': 0},
#  {'path': 'output\\M_0030_17y9m_1_segment_101.mp3',
#   'utterance': 'wired',
#   'class': 0},
#  {'path': 'output\\M_0030_17y9m_1_segment_102.mp3',
#   'utterance': 'up',
#   'class': 0},
#  {'path': 'output\\M_0030_17y9m_1_segment_103.mp3',
#   'utterance': 'to',
#   'class': 0},
#  {'path': 'output\\M_0030_17y9m_1_segment_104.mp3',
#   'utterance': 'stuff',
#   'class': 0},
#  {'path': 'output\\M_0030_17y9m_1_segment_105.mp3',
#   'utterance': 'WHICHCHCHCHCHCH',
#   'class': 7},
#  {'path': 'output\\M_0030_17y9m_1_segment_106.mp3',
#   'utterance': 'UM',
#   'class': 1},
#  {'path': 'output\\M_0030_17y9m_1_segment_107.mp3',
#   'utterance': 'C',
#   'class': 2},
#  {'path': 'output\\M_0030_17y9m_1_segment_108.mp3',
#   'utterance': 'AN',
#   'class': 2},
#  {'path': 'output\\M_0030_17y9m_1_segment_109.mp3',
#   'utterance': 'tell',
#   'class': 0},
#  {'path': 'output\\M_0030_17y9m_1_segment_11.mp3',
#   'utterance': 'i',
#   'class': 0},
#  {'path': 'output\\M_0030_17y9m_1_segment_110.mp3',
#   'utterance': 'if',
#   'class': 0},
#  {'path': 'output\\M_0030_17y9m_1_segment_111.mp3',
#   'utterance': "you've",
#   'class': 0},
#  {'path': 'output\\M_0030_17y9m_1_segment_112.mp3',
#   'utterance': 'hit',
#   'class': 0},
#  {'path': 'output\\M_0030_17y9m_1_segment_113.mp3',
#   'utterance': 'the',
#   'class': 0},
#  {'path': 'output\\M_0030_17y9m_1_segment_114.mp3',
#   'utterance': 'other',
#   'class': 0},
#  {'path': 'output\\M_0030_17y9m_1_segment_115.mp3',
#   'utterance': 'person',
#   'class': 0},
#  {'path': 'output\\M_0030_17y9m_1_segment_116.mp3',
#   'utterance': 'or',
#   'class': 0},
#  {'path': 'output\\M_0030_17y9m_1_segment_117.mp3',
#   'utterance': 'not',
#   'class': 0},
#  {'path': 'output\\M_0030_17y9m_1_segment_118.mp3',
#   'utterance': 'And',
#   'class': 0},
#  {'path': 'output\\M_0030_17y9m_1_segment_119.mp3',
#   'utterance': 'UM',
#   'class': 1},
#  {'path': 'output\\M_0030_17y9m_1_segment_12.mp3',
#   'utterance': 'started',
#   'class': 0},
#  {'path': 'output\\M_0030_17y9m_1_segment_120.mp3',
#   'utterance': "There's",
#   'class': 0},
#  {'path': 'output\\M_0030_17y9m_1_segment_121.mp3',
#   'utterance': 'a',
#   'class': 0},
#  {'path': 'output\\M_0030_17y9m_1_segment_122.mp3',
#   'utterance': 'metal',
#   'class': 0},
#  {'path': 'output\\M_0030_17y9m_1_segment_123.mp3',
#   'utterance': 'foil',
#   'class': 0},
#  {'path': 'output\\M_0030_17y9m_1_segment_124.mp3',
#   'utterance': 'often',
#   'class': 0},
#  {'path': 'output\\M_0030_17y9m_1_segment_125.mp3',
#   'utterance': 'which',
#   'class': 0},
#  {'path': 'output\\M_0030_17y9m_1_segment_126.mp3',
#   'utterance': 'means',
#   'class': 0},
#  {'path': 'output\\M_0030_17y9m_1_segment_127.mp3',
#   'utterance': 'that',
#   'class': 0},
#  {'path': 'output\\M_0030_17y9m_1_segment_128.mp3',
#   'utterance': 'light',
#   'class': 0},
#  {'path': 'output\\M_0030_17y9m_1_segment_129.mp3',
#   'utterance': "doesn't",
#   'class': 0},
#  {'path': 'output\\M_0030_17y9m_1_segment_13.mp3',
#   'utterance': 'fencing',
#   'class': 0},
#  {'path': 'output\\M_0030_17y9m_1_segment_130.mp3',
#   'utterance': 'come',
#   'class': 0},
#  {'path': 'output\\M_0030_17y9m_1_segment_131.mp3',
#   'utterance': 'up',
#   'class': 0},
#  {'path': 'output\\M_0030_17y9m_1_segment_132.mp3',
#   'utterance': 'if',
#   'class': 0},
#  {'path': 'output\\M_0030_17y9m_1_segment_133.mp3',
#   'utterance': 'you',
#   'class': 0},
#  {'path': 'output\\M_0030_17y9m_1_segment_134.mp3',
#   'utterance': 'hit',
#   'class': 0},
#  {'path': 'output\\M_0030_17y9m_1_segment_135.mp3',
#   'utterance': 'the',
#   'class': 0},
#  {'path': 'output\\M_0030_17y9m_1_segment_136.mp3',
#   'utterance': 'floor',
#   'class': 0},
#  {'path': 'output\\M_0030_17y9m_1_segment_137.mp3',
#   'utterance': 'And',
#   'class': 0},
#  {'path': 'output\\M_0030_17y9m_1_segment_138.mp3',
#   'utterance': 'UM',
#   'class': 1},
#  {'path': 'output\\M_0030_17y9m_1_segment_139.mp3',
#   'utterance': "I've",
#   'class': 0},
#  {'path': 'output\\M_0030_17y9m_1_segment_14.mp3',
#   'utterance': 'a',
#   'class': 0},
#  {'path': 'output\\M_0030_17y9m_1_segment_140.mp3',
#   'utterance': 'entered',
#   'class': 0},
#  {'path': 'output\\M_0030_17y9m_1_segment_141.mp3',
#   'utterance': 'a',
#   'class': 0},
#  {'path': 'output\\M_0030_17y9m_1_segment_142.mp3',
#   'utterance': 'few',
#   'class': 0},
#  {'path': 'output\\M_0030_17y9m_1_segment_143.mp3',
#   'utterance': 'competitions',
#   'class': 0},
#  {'path': 'output\\M_0030_17y9m_1_segment_144.mp3',
#   'utterance': 'i',
#   'class': 0},
#  {'path': 'output\\M_0030_17y9m_1_segment_145.mp3',
#   'utterance': 'did',
#   'class': 0},
#  {'path': 'output\\M_0030_17y9m_1_segment_146.mp3',
#   'utterance': 'quite',
#   'class': 0},
#  {'path': 'output\\M_0030_17y9m_1_segment_147.mp3',
#   'utterance': 'well',
#   'class': 0},
#  {'path': 'output\\M_0030_17y9m_1_segment_148.mp3',
#   'utterance': 'UM',
#   'class': 1},
#  {'path': 'output\\M_0030_17y9m_1_segment_149.mp3',
#   'utterance': 'about',
#   'class': 0},
#  {'path': 'output\\M_0030_17y9m_1_segment_15.mp3',
#   'utterance': 'couple',
#   'class': 0},
#  {'path': 'output\\M_0030_17y9m_1_segment_150.mp3',
#   'utterance': 'a',
#   'class': 0},
#  {'path': 'output\\M_0030_17y9m_1_segment_151.mp3',
#   'utterance': 'year',
#   'class': 0},
#  {'path': 'output\\M_0030_17y9m_1_segment_152.mp3',
#   'utterance': 'ago',
#   'class': 0},
#  {'path': 'output\\M_0030_17y9m_1_segment_153.mp3',
#   'utterance': 'when',
#   'class': 0},
#  {'path': 'output\\M_0030_17y9m_1_segment_154.mp3',
#   'utterance': 'i',
#   'class': 0},
#  {'path': 'output\\M_0030_17y9m_1_segment_155.mp3',
#   'utterance': 'came',
#   'class': 0},
#  {'path': 'output\\M_0030_17y9m_1_segment_156.mp3',
#   'utterance': 'SSSSSSEVENTH',
#   'class': 7},
#  {'path': 'output\\M_0030_17y9m_1_segment_157.mp3',
#   'utterance': 'in',
#   'class': 0},
#  {'path': 'output\\M_0030_17y9m_1_segment_158.mp3',
#   'utterance': 'Surrey',
#   'class': 0},
#  {'path': 'output\\M_0030_17y9m_1_segment_159.mp3',
#   'utterance': 'UM',
#   'class': 1},
#  {'path': 'output\\M_0030_17y9m_1_segment_16.mp3',
#   'utterance': 'of',
#   'class': 0},
#  {'path': 'output\\M_0030_17y9m_1_segment_160.mp3',
#   'utterance': 'which',
#   'class': 0},
#  {'path': 'output\\M_0030_17y9m_1_segment_161.mp3',
#   'utterance': "wasn't",
#   'class': 0},
#  {'path': 'output\\M_0030_17y9m_1_segment_162.mp3',
#   'utterance': 'bad',
#   'class': 0},
#  {'path': 'output\\M_0030_17y9m_1_segment_163.mp3',
#   'utterance': 'UM',
#   'class': 1},
#  {'path': 'output\\M_0030_17y9m_1_segment_164.mp3',
#   'utterance': "I've",
#   'class': 0},
#  {'path': 'output\\M_0030_17y9m_1_segment_165.mp3',
#   'utterance': 'not',
#   'class': 0},
#  {'path': 'output\\M_0030_17y9m_1_segment_166.mp3',
#   'utterance': 'been',
#   'class': 0},
#  {'path': 'output\\M_0030_17y9m_1_segment_167.mp3',
#   'utterance': 'doing',
#   'class': 0},
#  {'path': 'output\\M_0030_17y9m_1_segment_168.mp3',
#   'utterance': 'it',
#   'class': 0},
#  {'path': 'output\\M_0030_17y9m_1_segment_169.mp3',
#   'utterance': 'so',
#   'class': 0},
#  {'path': 'output\\M_0030_17y9m_1_segment_17.mp3',
#   'utterance': 'years',
#   'class': 0},
#  {'path': 'output\\M_0030_17y9m_1_segment_170.mp3',
#   'utterance': 'much',
#   'class': 0},
#  {'path': 'output\\M_0030_17y9m_1_segment_171.mp3',
#   'utterance': 'recently',
#   'class': 0},
#  {'path': 'output\\M_0030_17y9m_1_segment_172.mp3',
#   'utterance': 'though',
#   'class': 0},
#  {'path': 'output\\M_0030_17y9m_1_segment_173.mp3',
#   'utterance': 'but',
#   'class': 0},
#  {'path': 'output\\M_0030_17y9m_1_segment_174.mp3',
#   'utterance': 'i',
#   'class': 0},
#  {'path': 'output\\M_0030_17y9m_1_segment_175.mp3',
#   'utterance': 'have',
#   'class': 0},
#  {'path': 'output\\M_0030_17y9m_1_segment_176.mp3',
#   'utterance': 'done',
#   'class': 0},
#  {'path': 'output\\M_0030_17y9m_1_segment_177.mp3',
#   'utterance': 'a',
#   'class': 0},
#  {'path': 'output\\M_0030_17y9m_1_segment_178.mp3',
#   'utterance': 'bit',
#   'class': 0},
#  {'path': 'output\\M_0030_17y9m_1_segment_179.mp3',
#   'utterance': 'of',
#   'class': 0},
#  {'path': 'output\\M_0030_17y9m_1_segment_18.mp3',
#   'utterance': 'ago',
#   'class': 0},
#  {'path': 'output\\M_0030_17y9m_1_segment_180.mp3',
#   'utterance': 'sabre',
#   'class': 0},
#  {'path': 'output\\M_0030_17y9m_1_segment_181.mp3',
#   'utterance': 'UM',
#   'class': 1},
#  {'path': 'output\\M_0030_17y9m_1_segment_182.mp3',
#   'utterance': 'most',
#   'class': 0},
#  {'path': 'output\\M_0030_17y9m_1_segment_183.mp3',
#   'utterance': 'of',
#   'class': 0},
#  {'path': 'output\\M_0030_17y9m_1_segment_184.mp3',
#   'utterance': 'our',
#   'class': 0},
#  {'path': 'output\\M_0030_17y9m_1_segment_185.mp3',
#   'utterance': 'school',
#   'class': 0},
#  {'path': 'output\\M_0030_17y9m_1_segment_186.mp3',
#   'utterance': 'fencing',
#   'class': 0},
#  {'path': 'output\\M_0030_17y9m_1_segment_187.mp3',
#   'utterance': 'competitions',
#   'class': 0},
#  {'path': 'output\\M_0030_17y9m_1_segment_188.mp3',
#   'utterance': 'are',
#   'class': 0},
#  {'path': 'output\\M_0030_17y9m_1_segment_189.mp3',
#   'utterance': 'sabre',
#   'class': 0},
#  {'path': 'output\\M_0030_17y9m_1_segment_19.mp3',
#   'utterance': 'There',
#   'class': 0},
#  {'path': 'output\\M_0030_17y9m_1_segment_190.mp3',
#   'utterance': 'rather',
#   'class': 0},
#  {'path': 'output\\M_0030_17y9m_1_segment_191.mp3',
#   'utterance': 'than',
#   'class': 0},
#  {'path': 'output\\M_0030_17y9m_1_segment_192.mp3',
#   'utterance': 'epee',
#   'class': 0},
#  {'path': 'output\\M_0030_17y9m_1_segment_193.mp3',
#   'utterance': 'ERM',
#   'class': 1},
#  {'path': 'output\\M_0030_17y9m_1_segment_194.mp3',
#   'utterance': 'which',
#   'class': 0},
#  {'path': 'output\\M_0030_17y9m_1_segment_195.mp3',
#   'utterance': 'is',
#   'class': 0},
#  {'path': 'output\\M_0030_17y9m_1_segment_196.mp3',
#   'utterance': 'a',
#   'class': 0},
#  {'path': 'output\\M_0030_17y9m_1_segment_197.mp3',
#   'utterance': 'bit',
#   'class': 0},
#  {'path': 'output\\M_0030_17y9m_1_segment_198.mp3',
#   'utterance': 'of',
#   'class': 0},
#  {'path': 'output\\M_0030_17y9m_1_segment_199.mp3',
#   'utterance': 'a',
#   'class': 0},
#  {'path': 'output\\M_0030_17y9m_1_segment_2.mp3',
#   'utterance': 'going',
#   'class': 0},
#  {'path': 'output\\M_0030_17y9m_1_segment_20.mp3',
#   'utterance': 'are',
#   'class': 0},
#  {'path': 'output\\M_0030_17y9m_1_segment_200.mp3',
#   'utterance': 'pain',
#   'class': 0},
#  {'path': 'output\\M_0030_17y9m_1_segment_201.mp3',
#   'utterance': 'because',
#   'class': 0},
#  {'path': 'output\\M_0030_17y9m_1_segment_202.mp3',
#   'utterance': "it's",
#   'class': 0},
#  {'path': 'output\\M_0030_17y9m_1_segment_203.mp3',
#   'utterance': 'mostly',
#   'class': 0},
#  {'path': 'output\\M_0030_17y9m_1_segment_204.mp3',
#   'utterance': 'loads',
#   'class': 0},
#  {'path': 'output\\M_0030_17y9m_1_segment_205.mp3',
#   'utterance': 'of',
#   'class': 0},
#  {'path': 'output\\M_0030_17y9m_1_segment_206.mp3',
#   'utterance': 'inexperienced',
#   'class': 0},
#  {'path': 'output\\M_0030_17y9m_1_segment_207.mp3',
#   'utterance': 'people',
#   'class': 0},
#  {'path': 'output\\M_0030_17y9m_1_segment_208.mp3',
#   'utterance': 'WHO',
#   'class': 6},
#  {'path': 'output\\M_0030_17y9m_1_segment_209.mp3',
#   'utterance': 'JUST',
#   'class': 6},
#  {'path': 'output\\M_0030_17y9m_1_segment_21.mp3',
#   'utterance': 'three',
#   'class': 0},
#  {'path': 'output\\M_0030_17y9m_1_segment_210.mp3',
#   'utterance': 'WILL',
#   'class': 6},
#  {'path': 'output\\M_0030_17y9m_1_segment_211.mp3',
#   'utterance': 'WHO',
#   'class': 6},
#  {'path': 'output\\M_0030_17y9m_1_segment_212.mp3',
#   'utterance': 'JUST',
#   'class': 6},
#  {'path': 'output\\M_0030_17y9m_1_segment_213.mp3',
#   'utterance': 'hit',
#   'class': 0},
#  {'path': 'output\\M_0030_17y9m_1_segment_214.mp3',
#   'utterance': 'you',
#   'class': 0},
#  {'path': 'output\\M_0030_17y9m_1_segment_215.mp3',
#   'utterance': 'and',
#   'class': 0},
#  {'path': 'output\\M_0030_17y9m_1_segment_216.mp3',
#   'utterance': 'i',
#   'class': 0},
#  {'path': 'output\\M_0030_17y9m_1_segment_217.mp3',
#   'utterance': 'would',
#   'class': 0},
#  {'path': 'output\\M_0030_17y9m_1_segment_218.mp3',
#   'utterance': 'always',
#   'class': 0},
#  ...]

# %%
# Create a dataset from the list
dataset = Dataset.from_pandas(pd.DataFrame(data))

# %%
dataset
# Out:
# Dataset({
#     features: ['path', 'utterance', 'class'],
#     num_rows: 5534
# })

# %%
from datasets import Features, ClassLabel, Value

features = Features({
    'path': Audio(sampling_rate=16_000),
    'utterance': Value('string'),
    'class': ClassLabel(num_classes=8)  # Adjust num_classes as necessary
})

# %%
features
# Out:
# {'path': Audio(sampling_rate=16000, mono=True, decode=True, id=None),
#  'utterance': Value(dtype='string', id=None),
#  'class': ClassLabel(names=['0', '1', '2', '3', '4', '5', '6', '7'], id=None)}

# %%
# Cast the dataset to these features
dataset = dataset.cast(features)
# Out:
# Casting the dataset:   0%|          | 0/5534 [00:00<?, ? examples/s]

# %%
dataset
# Out:
# Dataset({
#     features: ['path', 'utterance', 'class'],
#     num_rows: 5534
# })

# %%
dataset.push_to_hub("HamdanXI/uclass_clipped_labeled")
# Out:
# Map:   0%|          | 0/5534 [00:00<?, ? examples/s]
# Pushing dataset shards to the dataset hub:   0%|          | 0/1 [00:00<?, ?it/s]
# Creating parquet from Arrow format:   0%|          | 0/56 [00:00<?, ?ba/s]
